# %% [markdown]
# <a href="https://colab.research.google.com/github/JuneRaz/EthanThes/blob/main/Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Clone the tensorflow models repository from GitHub
# !pip uninstall Cython -y # Temporary fix for "No module named 'object_detection'" error
# !git clone --depth 1 https://github.com/tensorflow/models
# Out:
# Found existing installation: Cython 3.0.10
# Uninstalling Cython-3.0.10:
#   Successfully uninstalled Cython-3.0.10
# fatal: destination path 'models' already exists and is not an empty directory.

# %%
# Copy setup files into models/research folder
# %%bash
cd models/research/
protoc object_detection/protos/*.proto --python_out=.
#cp object_detection/packages/tf2/setup.py .

# %%
# Modify setup.py file to install the tf-models-official repository targeted at TF v2.8.0
import re
with open('/content/models/research/object_detection/packages/tf2/setup.py') as f:
    s = f.read()

with open('/content/models/research/setup.py', 'w') as f:
    # Set fine_tune_checkpoint path
    s = re.sub('tf-models-official>=2.5.1',
               'tf-models-official==2.8.0', s)
    f.write(s)

# %%
# Install the Object Detection API (NOTE: This block takes about 10 minutes to finish executing)

# Need to do a temporary fix with PyYAML because Colab isn't able to install PyYAML v5.4.1
# !pip install pyyaml==5.3
# !pip install /content/models/research/

# Need to downgrade to TF v2.8.0 due to Colab compatibility bug with TF v2.10 (as of 10/03/22)
# !pip install tensorflow==2.8.0

# Install CUDA version 11.0 (to maintain compatibility with TF v2.8.0)
# !pip install tensorflow_io==0.23.1
# !wget https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-ubuntu1804.pin
# !mv cuda-ubuntu1804.pin /etc/apt/preferences.d/cuda-repository-pin-600
# !wget http://developer.download.nvidia.com/compute/cuda/11.0.2/local_installers/cuda-repo-ubuntu1804-11-0-local_11.0.2-450.51.05-1_amd64.deb
# !dpkg -i cuda-repo-ubuntu1804-11-0-local_11.0.2-450.51.05-1_amd64.deb
# !apt-key add /var/cuda-repo-ubuntu1804-11-0-local/7fa2af80.pub
# !apt-get update && sudo apt-get install cuda-toolkit-11-0
# !export LD_LIBRARY_PATH=/usr/local/cuda-11.0/lib64:$LD_LIBRARY_PATH
# Out:
# Collecting pyyaml==5.3
#   Using cached PyYAML-5.3-cp310-cp310-linux_x86_64.whl
# Installing collected packages: pyyaml
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0.1
#     Uninstalling PyYAML-6.0.1:
#       Successfully uninstalled PyYAML-6.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-models-official 2.8.0 requires Cython, which is not installed.
# dask 2023.8.1 requires pyyaml>=5.3.1, but you have pyyaml 5.3 which is incompatible.
# distributed 2023.8.1 requires pyyaml>=5.3.1, but you have pyyaml 5.3 which is incompatible.
# flax 0.8.2 requires PyYAML>=5.4.1, but you have pyyaml 5.3 which is incompatible.
# roboflow 1.1.27 requires PyYAML>=5.3.1, but you have pyyaml 5.3 which is incompatible.
# Successfully installed pyyaml-5.3
# Processing ./models/research
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: avro-python3 in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (1.10.2)
# Requirement already satisfied: apache-beam in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (2.55.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (9.4.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (4.9.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (3.7.1)
# Collecting Cython (from object-detection==0.1)
#   Using cached Cython-3.0.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (21.6.0)
# Requirement already satisfied: tf-slim in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (1.16.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (2.0.7)
# Requirement already satisfied: lvis in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (0.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (1.11.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (2.0.3)
# Requirement already satisfied: tf-models-official==2.8.0 in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (2.8.0)
# Requirement already satisfied: tensorflow_io in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (0.23.1)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (2.8.0)
# Requirement already satisfied: pyparsing==2.4.7 in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (2.4.7)
# Requirement already satisfied: sacrebleu<=2.2.0 in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (2.2.0)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object-detection==0.1) (0.5.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object-detection==0.1) (2.84.0)
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object-detection==0.1) (1.5.16)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object-detection==0.1) (1.25.2)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object-detection==0.1) (4.1.3)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object-detection==0.1) (4.8.0.74)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object-detection==0.1) (5.9.5)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object-detection==0.1) (9.0.0)
# Requirement already satisfied: pyyaml<6.0,>=5.1 in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object-detection==0.1) (5.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object-detection==0.1) (0.1.99)
# Requirement already satisfied: seqeval in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object-detection==0.1) (1.2.2)
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object-detection==0.1) (0.23.0)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object-detection==0.1) (4.9.4)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object-detection==0.1) (0.16.1)
# Requirement already satisfied: tensorflow-model-optimization>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object-detection==0.1) (0.8.0)
# Requirement already satisfied: tensorflow-text~=2.8.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object-detection==0.1) (2.8.2)
# Requirement already satisfied: tensorflow~=2.8.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official==2.8.0->object-detection==0.1) (2.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->object-detection==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->object-detection==0.1) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->object-detection==0.1) (2024.1)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2.8.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2023.12.25)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.9.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.4.6)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from tf-slim->object-detection==0.1) (1.4.0)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (1.7)
# Requirement already satisfied: orjson<4,>=3.9.7 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (3.10.1)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (0.3.1.1)
# Requirement already satisfied: cloudpickle~=2.2.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (2.2.1)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (1.9.4)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (0.19)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (1.62.2)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (2.7.3)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (0.22.0)
# Requirement already satisfied: js2py<1,>=0.74 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (0.74)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (4.19.2)
# Requirement already satisfied: jsonpickle<4.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (3.0.4)
# Requirement already satisfied: objsize<0.8.0,>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (0.7.0)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (24.0)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (4.6.3)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (1.23.0)
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.*,!=4.22.0,!=4.23.*,!=4.24.*,<4.26.0,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (3.20.3)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (1.4.2)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (4.11.0)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (0.22.0)
# Requirement already satisfied: pyarrow<15.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix<1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (0.6)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from lvis->object-detection==0.1) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from lvis->object-detection==0.1) (1.4.5)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.10/dist-packages (from lvis->object-detection==0.1) (4.8.0.76)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->object-detection==0.1) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->object-detection==0.1) (4.51.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow_io->object-detection==0.1) (0.23.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0->object-detection==0.1) (2.27.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0->object-detection==0.1) (0.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0->object-detection==0.1) (2.11.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official==2.8.0->object-detection==0.1) (4.1.1)
# Requirement already satisfied: docopt in /usr/local/lib/python3.10/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam->object-detection==0.1) (0.6.2)
# Requirement already satisfied: tzlocal>=1.2 in /usr/local/lib/python3.10/dist-packages (from js2py<1,>=0.74->apache-beam->object-detection==0.1) (5.2)
# Requirement already satisfied: pyjsparser>=2.5.1 in /usr/local/lib/python3.10/dist-packages (from js2py<1,>=0.74->apache-beam->object-detection==0.1) (2.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam->object-detection==0.1) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam->object-detection==0.1) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam->object-detection==0.1) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam->object-detection==0.1) (0.18.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official==2.8.0->object-detection==0.1) (2023.7.22)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official==2.8.0->object-detection==0.1) (4.66.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official==2.8.0->object-detection==0.1) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official==2.8.0->object-detection==0.1) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official==2.8.0->object-detection==0.1) (6.1.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo<5.0.0,>=3.8.0->apache-beam->object-detection==0.1) (2.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (2.10)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (24.3.25)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (3.9.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (3.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (67.7.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (2.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (1.14.1)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (2.8.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (2.8.0.dev2021122109)
# Requirement already satisfied: tf-keras>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-hub>=0.6.0->tf-models-official==2.8.0->object-detection==0.1) (2.15.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official==2.8.0->object-detection==0.1) (0.1.8)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official==2.8.0->object-detection==0.1) (0.6.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official==2.8.0->object-detection==0.1) (0.4.0)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official==2.8.0->object-detection==0.1) (4.9)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval->tf-models-official==2.8.0->object-detection==0.1) (1.2.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons->tf-models-official==2.8.0->object-detection==0.1) (2.13.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (8.1.7)
# Requirement already satisfied: etils[enp,epath,etree]>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (1.7.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (2.3)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (1.14.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (0.10.2)
# Requirement already satisfied: array-record>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (0.5.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (0.43.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (2023.6.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (6.4.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,etree]>=0.9.0->tensorflow-datasets->tf-models-official==2.8.0->object-detection==0.1) (3.18.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official==2.8.0->object-detection==0.1) (1.63.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official==2.8.0->object-detection==0.1) (5.3.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official==2.8.0->object-detection==0.1) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official==2.8.0->object-detection==0.1) (3.4.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (3.0.2)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle>=1.3.9->tf-models-official==2.8.0->object-detection==0.1) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official==2.8.0->object-detection==0.1) (1.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (2.1.5)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->tf-models-official==2.8.0->object-detection==0.1) (3.2.2)
# Building wheels for collected packages: object-detection
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1697352 sha256=bf9b4a757a11dbdd80eaa1291c508e5990f95e4c6d3a03c13a52dcf9f8f96b95
#   Stored in directory: /tmp/pip-ephem-wheel-cache-yfiduuwf/wheels/53/dd/70/2de274d6c443c69d367bd6a5606f95e5a6df61aacf1435ec0d
# Successfully built object-detection
# Installing collected packages: Cython, object-detection
#   Attempting uninstall: object-detection
#     Found existing installation: object-detection 0.1
#     Uninstalling object-detection-0.1:
#       Successfully uninstalled object-detection-0.1
# Successfully installed Cython-3.0.10 object-detection-0.1
# Requirement already satisfied: tensorflow==2.8.0 in /usr/local/lib/python3.10/dist-packages (2.8.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (24.3.25)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (3.9.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.14.1)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (2.8.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (2.8.0.dev2021122109)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (2.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (0.23.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.8.0) (1.62.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.8.0) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.0.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.2.2)
# Requirement already satisfied: tensorflow_io==0.23.1 in /usr/local/lib/python3.10/dist-packages (0.23.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow_io==0.23.1) (0.23.1)
# --2024-04-23 23:07:46--  https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-ubuntu1804.pin
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 152.199.39.144
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.39.144|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 190 [application/octet-stream]
# Saving to: ‘cuda-ubuntu1804.pin’
#
# cuda-ubuntu1804.pin 100%[===================>]     190  --.-KB/s    in 0s
#
# 2024-04-23 23:07:46 (6.22 MB/s) - ‘cuda-ubuntu1804.pin’ saved [190/190]
#
# --2024-04-23 23:07:46--  http://developer.download.nvidia.com/compute/cuda/11.0.2/local_installers/cuda-repo-ubuntu1804-11-0-local_11.0.2-450.51.05-1_amd64.deb
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 152.199.39.144
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.39.144|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://developer.download.nvidia.com/compute/cuda/11.0.2/local_installers/cuda-repo-ubuntu1804-11-0-local_11.0.2-450.51.05-1_amd64.deb [following]
# --2024-04-23 23:07:46--  https://developer.download.nvidia.com/compute/cuda/11.0.2/local_installers/cuda-repo-ubuntu1804-11-0-local_11.0.2-450.51.05-1_amd64.deb
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.39.144|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2273753684 (2.1G) [application/x-deb]
# Saving to: ‘cuda-repo-ubuntu1804-11-0-local_11.0.2-450.51.05-1_amd64.deb.1’
#
# cuda-repo-ubuntu180 100%[===================>]   2.12G   193MB/s    in 10s
#
# 2024-04-23 23:07:57 (209 MB/s) - ‘cuda-repo-ubuntu1804-11-0-local_11.0.2-450.51.05-1_amd64.deb.1’ saved [2273753684/2273753684]
#
# (Reading database ... 134798 files and directories currently installed.)
# Preparing to unpack cuda-repo-ubuntu1804-11-0-local_11.0.2-450.51.05-1_amd64.deb ...
# Unpacking cuda-repo-ubuntu1804-11-0-local (11.0.2-450.51.05-1) over (11.0.2-450.51.05-1) ...
# Setting up cuda-repo-ubuntu1804-11-0-local (11.0.2-450.51.05-1) ...
# Warning: apt-key is deprecated. Manage keyring files in trusted.gpg.d instead (see apt-key(8)).
# OK
# Get:1 file:/var/cuda-repo-ubuntu1804-11-0-local  InRelease
# Ign:1 file:/var/cuda-repo-ubuntu1804-11-0-local  InRelease
# Get:2 file:/var/cuda-repo-ubuntu1804-11-0-local  Release [564 B]
# Get:2 file:/var/cuda-repo-ubuntu1804-11-0-local  Release [564 B]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:6 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:10 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: file:/var/cuda-repo-ubuntu1804-11-0-local/Release.gpg: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# cuda-toolkit-11-0 is already the newest version (11.0.2-1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
# !python /content/models/research/object_detection/builders/model_builder_tf2_test.py
# Out:
# Running tests under Python 3.10.12: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2024-04-23 23:08:38.558132: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# W0423 23:08:38.976337 133085962433152 model_builder.py:1112] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 2.57s
# I0423 23:08:39.397300 133085962433152 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 2.57s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.53s
# I0423 23:08:39.928600 133085962433152 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.53s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.24s
# I0423 23:08:40.172658 133085962433152 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.24s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.26s
# I0423 23:08:40.430384 133085962433152 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.26s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 2.11s
# I0423 23:08:42.541664 133085962433152 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 2.11s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I0423 23:08:42.543560 133085962433152 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.04s
# I0423 23:08:42.579184 133085962433152 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.04s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.02s
# I0423 23:08:42.601302 133085962433152 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# I0423 23:08:42.624739 133085962433152 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.17s
# I0423 23:08:42.796274 133085962433152 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.17s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.15s
# I0423 23:08:42.948899 133085962433152 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.15s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.17s
# I0423 23:08:43.123187 133085962433152 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.17s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.15s
# I0423 23:08:43.278272 133085962433152 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.15s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.14s
# I0423 23:08:43.418101 133085962433152 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.14s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.04s
# I0423 23:08:43.462784 133085962433152 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.04s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I0423 23:08:43.892179 133085962433152 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b0
# I0423 23:08:43.892410 133085962433152 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 64
# I0423 23:08:43.892536 133085962433152 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 3
# I0423 23:08:43.896412 133085962433152 efficientnet_model.py:144] round_filter input=32 output=32
# I0423 23:08:43.919853 133085962433152 efficientnet_model.py:144] round_filter input=32 output=32
# I0423 23:08:43.920003 133085962433152 efficientnet_model.py:144] round_filter input=16 output=16
# I0423 23:08:44.012548 133085962433152 efficientnet_model.py:144] round_filter input=16 output=16
# I0423 23:08:44.012753 133085962433152 efficientnet_model.py:144] round_filter input=24 output=24
# I0423 23:08:44.321274 133085962433152 efficientnet_model.py:144] round_filter input=24 output=24
# I0423 23:08:44.321489 133085962433152 efficientnet_model.py:144] round_filter input=40 output=40
# I0423 23:08:44.727955 133085962433152 efficientnet_model.py:144] round_filter input=40 output=40
# I0423 23:08:44.728179 133085962433152 efficientnet_model.py:144] round_filter input=80 output=80
# I0423 23:08:45.281933 133085962433152 efficientnet_model.py:144] round_filter input=80 output=80
# I0423 23:08:45.282140 133085962433152 efficientnet_model.py:144] round_filter input=112 output=112
# I0423 23:08:46.012580 133085962433152 efficientnet_model.py:144] round_filter input=112 output=112
# I0423 23:08:46.012801 133085962433152 efficientnet_model.py:144] round_filter input=192 output=192
# I0423 23:08:46.503277 133085962433152 efficientnet_model.py:144] round_filter input=192 output=192
# I0423 23:08:46.503548 133085962433152 efficientnet_model.py:144] round_filter input=320 output=320
# I0423 23:08:46.607253 133085962433152 efficientnet_model.py:144] round_filter input=1280 output=1280
# I0423 23:08:46.655333 133085962433152 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0423 23:08:46.762330 133085962433152 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b1
# I0423 23:08:46.769563 133085962433152 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 88
# I0423 23:08:46.769688 133085962433152 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 4
# I0423 23:08:46.772253 133085962433152 efficientnet_model.py:144] round_filter input=32 output=32
# I0423 23:08:46.813866 133085962433152 efficientnet_model.py:144] round_filter input=32 output=32
# I0423 23:08:46.814019 133085962433152 efficientnet_model.py:144] round_filter input=16 output=16
# I0423 23:08:47.030179 133085962433152 efficientnet_model.py:144] round_filter input=16 output=16
# I0423 23:08:47.030400 133085962433152 efficientnet_model.py:144] round_filter input=24 output=24
# I0423 23:08:47.418997 133085962433152 efficientnet_model.py:144] round_filter input=24 output=24
# I0423 23:08:47.419189 133085962433152 efficientnet_model.py:144] round_filter input=40 output=40
# I0423 23:08:48.028803 133085962433152 efficientnet_model.py:144] round_filter input=40 output=40
# I0423 23:08:48.039616 133085962433152 efficientnet_model.py:144] round_filter input=80 output=80
# I0423 23:08:48.603011 133085962433152 efficientnet_model.py:144] round_filter input=80 output=80
# I0423 23:08:48.603223 133085962433152 efficientnet_model.py:144] round_filter input=112 output=112
# I0423 23:08:49.906200 133085962433152 efficientnet_model.py:144] round_filter input=112 output=112
# I0423 23:08:49.906397 133085962433152 efficientnet_model.py:144] round_filter input=192 output=192
# I0423 23:08:51.322324 133085962433152 efficientnet_model.py:144] round_filter input=192 output=192
# I0423 23:08:51.322552 133085962433152 efficientnet_model.py:144] round_filter input=320 output=320
# I0423 23:08:52.003370 133085962433152 efficientnet_model.py:144] round_filter input=1280 output=1280
# I0423 23:08:52.150189 133085962433152 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0423 23:08:52.484591 133085962433152 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b2
# I0423 23:08:52.484802 133085962433152 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 112
# I0423 23:08:52.484891 133085962433152 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 5
# I0423 23:08:52.487410 133085962433152 efficientnet_model.py:144] round_filter input=32 output=32
# I0423 23:08:52.557581 133085962433152 efficientnet_model.py:144] round_filter input=32 output=32
# I0423 23:08:52.557762 133085962433152 efficientnet_model.py:144] round_filter input=16 output=16
# I0423 23:08:52.842887 133085962433152 efficientnet_model.py:144] round_filter input=16 output=16
# I0423 23:08:52.843101 133085962433152 efficientnet_model.py:144] round_filter input=24 output=24
# I0423 23:08:53.515953 133085962433152 efficientnet_model.py:144] round_filter input=24 output=24
# I0423 23:08:53.516145 133085962433152 efficientnet_model.py:144] round_filter input=40 output=48
# I0423 23:08:53.930635 133085962433152 efficientnet_model.py:144] round_filter input=40 output=48
# I0423 23:08:53.930835 133085962433152 efficientnet_model.py:144] round_filter input=80 output=88
# I0423 23:08:54.738327 133085962433152 efficientnet_model.py:144] round_filter input=80 output=88
# I0423 23:08:54.738569 133085962433152 efficientnet_model.py:144] round_filter input=112 output=120
# I0423 23:08:55.430193 133085962433152 efficientnet_model.py:144] round_filter input=112 output=120
# I0423 23:08:55.430415 133085962433152 efficientnet_model.py:144] round_filter input=192 output=208
# I0423 23:08:56.077500 133085962433152 efficientnet_model.py:144] round_filter input=192 output=208
# I0423 23:08:56.077734 133085962433152 efficientnet_model.py:144] round_filter input=320 output=352
# I0423 23:08:56.341260 133085962433152 efficientnet_model.py:144] round_filter input=1280 output=1408
# I0423 23:08:56.406692 133085962433152 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.1, depth_coefficient=1.2, resolution=260, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0423 23:08:56.518680 133085962433152 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b3
# I0423 23:08:56.518903 133085962433152 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 160
# I0423 23:08:56.519006 133085962433152 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 6
# I0423 23:08:56.521681 133085962433152 efficientnet_model.py:144] round_filter input=32 output=40
# I0423 23:08:56.554364 133085962433152 efficientnet_model.py:144] round_filter input=32 output=40
# I0423 23:08:56.554528 133085962433152 efficientnet_model.py:144] round_filter input=16 output=24
# I0423 23:08:56.873952 133085962433152 efficientnet_model.py:144] round_filter input=16 output=24
# I0423 23:08:56.882549 133085962433152 efficientnet_model.py:144] round_filter input=24 output=32
# I0423 23:08:57.232541 133085962433152 efficientnet_model.py:144] round_filter input=24 output=32
# I0423 23:08:57.232719 133085962433152 efficientnet_model.py:144] round_filter input=40 output=48
# I0423 23:08:57.486287 133085962433152 efficientnet_model.py:144] round_filter input=40 output=48
# I0423 23:08:57.486481 133085962433152 efficientnet_model.py:144] round_filter input=80 output=96
# I0423 23:08:57.884522 133085962433152 efficientnet_model.py:144] round_filter input=80 output=96
# I0423 23:08:57.884711 133085962433152 efficientnet_model.py:144] round_filter input=112 output=136
# I0423 23:08:58.300135 133085962433152 efficientnet_model.py:144] round_filter input=112 output=136
# I0423 23:08:58.300342 133085962433152 efficientnet_model.py:144] round_filter input=192 output=232
# I0423 23:08:58.817691 133085962433152 efficientnet_model.py:144] round_filter input=192 output=232
# I0423 23:08:58.817866 133085962433152 efficientnet_model.py:144] round_filter input=320 output=384
# I0423 23:08:58.974277 133085962433152 efficientnet_model.py:144] round_filter input=1280 output=1536
# I0423 23:08:59.006006 133085962433152 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.2, depth_coefficient=1.4, resolution=300, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0423 23:08:59.070644 133085962433152 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b4
# I0423 23:08:59.070800 133085962433152 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 224
# I0423 23:08:59.070877 133085962433152 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 7
# I0423 23:08:59.072369 133085962433152 efficientnet_model.py:144] round_filter input=32 output=48
# I0423 23:08:59.088550 133085962433152 efficientnet_model.py:144] round_filter input=32 output=48
# I0423 23:08:59.088690 133085962433152 efficientnet_model.py:144] round_filter input=16 output=24
# I0423 23:08:59.214801 133085962433152 efficientnet_model.py:144] round_filter input=16 output=24
# I0423 23:08:59.214967 133085962433152 efficientnet_model.py:144] round_filter input=24 output=32
# I0423 23:08:59.838477 133085962433152 efficientnet_model.py:144] round_filter input=24 output=32
# I0423 23:08:59.838652 133085962433152 efficientnet_model.py:144] round_filter input=40 output=56
# I0423 23:09:00.150251 133085962433152 efficientnet_model.py:144] round_filter input=40 output=56
# I0423 23:09:00.150427 133085962433152 efficientnet_model.py:144] round_filter input=80 output=112
# I0423 23:09:00.648968 133085962433152 efficientnet_model.py:144] round_filter input=80 output=112
# I0423 23:09:00.649155 133085962433152 efficientnet_model.py:144] round_filter input=112 output=160
# I0423 23:09:01.127950 133085962433152 efficientnet_model.py:144] round_filter input=112 output=160
# I0423 23:09:01.128133 133085962433152 efficientnet_model.py:144] round_filter input=192 output=272
# I0423 23:09:01.808783 133085962433152 efficientnet_model.py:144] round_filter input=192 output=272
# I0423 23:09:01.808967 133085962433152 efficientnet_model.py:144] round_filter input=320 output=448
# I0423 23:09:01.962860 133085962433152 efficientnet_model.py:144] round_filter input=1280 output=1792
# I0423 23:09:01.992970 133085962433152 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.4, depth_coefficient=1.8, resolution=380, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0423 23:09:02.067344 133085962433152 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b5
# I0423 23:09:02.067508 133085962433152 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 288
# I0423 23:09:02.067584 133085962433152 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 7
# I0423 23:09:02.069069 133085962433152 efficientnet_model.py:144] round_filter input=32 output=48
# I0423 23:09:02.087300 133085962433152 efficientnet_model.py:144] round_filter input=32 output=48
# I0423 23:09:02.087419 133085962433152 efficientnet_model.py:144] round_filter input=16 output=24
# I0423 23:09:02.274038 133085962433152 efficientnet_model.py:144] round_filter input=16 output=24
# I0423 23:09:02.274202 133085962433152 efficientnet_model.py:144] round_filter input=24 output=40
# I0423 23:09:02.697475 133085962433152 efficientnet_model.py:144] round_filter input=24 output=40
# I0423 23:09:02.697641 133085962433152 efficientnet_model.py:144] round_filter input=40 output=64
# I0423 23:09:03.101601 133085962433152 efficientnet_model.py:144] round_filter input=40 output=64
# I0423 23:09:03.101764 133085962433152 efficientnet_model.py:144] round_filter input=80 output=128
# I0423 23:09:03.781447 133085962433152 efficientnet_model.py:144] round_filter input=80 output=128
# I0423 23:09:03.781654 133085962433152 efficientnet_model.py:144] round_filter input=112 output=176
# I0423 23:09:04.529780 133085962433152 efficientnet_model.py:144] round_filter input=112 output=176
# I0423 23:09:04.529998 133085962433152 efficientnet_model.py:144] round_filter input=192 output=304
# I0423 23:09:05.512185 133085962433152 efficientnet_model.py:144] round_filter input=192 output=304
# I0423 23:09:05.512386 133085962433152 efficientnet_model.py:144] round_filter input=320 output=512
# I0423 23:09:05.836994 133085962433152 efficientnet_model.py:144] round_filter input=1280 output=2048
# I0423 23:09:05.876652 133085962433152 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0423 23:09:06.398488 133085962433152 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b6
# I0423 23:09:06.398694 133085962433152 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 384
# I0423 23:09:06.398772 133085962433152 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 8
# I0423 23:09:06.401201 133085962433152 efficientnet_model.py:144] round_filter input=32 output=56
# I0423 23:09:06.424340 133085962433152 efficientnet_model.py:144] round_filter input=32 output=56
# I0423 23:09:06.424548 133085962433152 efficientnet_model.py:144] round_filter input=16 output=32
# I0423 23:09:06.731550 133085962433152 efficientnet_model.py:144] round_filter input=16 output=32
# I0423 23:09:06.732098 133085962433152 efficientnet_model.py:144] round_filter input=24 output=40
# I0423 23:09:07.254252 133085962433152 efficientnet_model.py:144] round_filter input=24 output=40
# I0423 23:09:07.254451 133085962433152 efficientnet_model.py:144] round_filter input=40 output=72
# I0423 23:09:07.748317 133085962433152 efficientnet_model.py:144] round_filter input=40 output=72
# I0423 23:09:07.748513 133085962433152 efficientnet_model.py:144] round_filter input=80 output=144
# I0423 23:09:08.413072 133085962433152 efficientnet_model.py:144] round_filter input=80 output=144
# I0423 23:09:08.413248 133085962433152 efficientnet_model.py:144] round_filter input=112 output=200
# I0423 23:09:09.064478 133085962433152 efficientnet_model.py:144] round_filter input=112 output=200
# I0423 23:09:09.064657 133085962433152 efficientnet_model.py:144] round_filter input=192 output=344
# I0423 23:09:09.943160 133085962433152 efficientnet_model.py:144] round_filter input=192 output=344
# I0423 23:09:09.943348 133085962433152 efficientnet_model.py:144] round_filter input=320 output=576
# I0423 23:09:10.173432 133085962433152 efficientnet_model.py:144] round_filter input=1280 output=2304
# I0423 23:09:10.205392 133085962433152 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0423 23:09:10.307516 133085962433152 ssd_efficientnet_bifpn_feature_extractor.py:161] EfficientDet EfficientNet backbone version: efficientnet-b7
# I0423 23:09:10.307670 133085962433152 ssd_efficientnet_bifpn_feature_extractor.py:163] EfficientDet BiFPN num filters: 384
# I0423 23:09:10.307743 133085962433152 ssd_efficientnet_bifpn_feature_extractor.py:164] EfficientDet BiFPN num iterations: 8
# I0423 23:09:10.309356 133085962433152 efficientnet_model.py:144] round_filter input=32 output=64
# I0423 23:09:10.324178 133085962433152 efficientnet_model.py:144] round_filter input=32 output=64
# I0423 23:09:10.324289 133085962433152 efficientnet_model.py:144] round_filter input=16 output=32
# I0423 23:09:10.568890 133085962433152 efficientnet_model.py:144] round_filter input=16 output=32
# I0423 23:09:10.569061 133085962433152 efficientnet_model.py:144] round_filter input=24 output=48
# I0423 23:09:11.110485 133085962433152 efficientnet_model.py:144] round_filter input=24 output=48
# I0423 23:09:11.110673 133085962433152 efficientnet_model.py:144] round_filter input=40 output=80
# I0423 23:09:11.677942 133085962433152 efficientnet_model.py:144] round_filter input=40 output=80
# I0423 23:09:11.678124 133085962433152 efficientnet_model.py:144] round_filter input=80 output=160
# I0423 23:09:12.516605 133085962433152 efficientnet_model.py:144] round_filter input=80 output=160
# I0423 23:09:12.516773 133085962433152 efficientnet_model.py:144] round_filter input=112 output=224
# I0423 23:09:13.697393 133085962433152 efficientnet_model.py:144] round_filter input=112 output=224
# I0423 23:09:13.697585 133085962433152 efficientnet_model.py:144] round_filter input=192 output=384
# I0423 23:09:14.752477 133085962433152 efficientnet_model.py:144] round_filter input=192 output=384
# I0423 23:09:14.752649 133085962433152 efficientnet_model.py:144] round_filter input=320 output=640
# I0423 23:09:15.069303 133085962433152 efficientnet_model.py:144] round_filter input=1280 output=2560
# I0423 23:09:15.108793 133085962433152 efficientnet_model.py:454] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 31.76s
# I0423 23:09:15.227446 133085962433152 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 31.76s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.01s
# I0423 23:09:15.240131 133085962433152 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.01s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0423 23:09:15.241753 133085962433152 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0423 23:09:15.242217 133085962433152 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0423 23:09:15.243670 133085962433152 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0423 23:09:15.244988 133085962433152 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0423 23:09:15.245416 133085962433152 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0423 23:09:15.246351 133085962433152 test_util.py:2373] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 38.421s
#
# OK (skipped=1)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="gqI5ydFAf4Yh97RTmvwA")
project = rf.workspace("junnie").project("newyawn")
version = project.version(4)
dataset = version.download("tensorflow")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.10/dist-packages (1.1.27)
# Requirement already satisfied: certifi==2023.7.22 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2023.7.22)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.10.0)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.25.2)
# Requirement already satisfied: opencv-python-headless==4.8.0.74 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.8.0.74)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.2)
# Collecting PyYAML>=5.3.1 (from roboflow)
#   Using cached PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.4.27)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.51.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (2.4.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.2)
# Installing collected packages: PyYAML
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 5.3
#     Uninstalling PyYAML-5.3:
#       Successfully uninstalled PyYAML-5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-models-official 2.8.0 requires pyyaml<6.0,>=5.1, but you have pyyaml 6.0.1 which is incompatible.
# Successfully installed PyYAML-6.0.1
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in NewYawn-4 to tensorflow:: 100%|██████████| 19641/19641 [00:02<00:00, 8436.65it/s]
# Extracting Dataset Version Zip to NewYawn-4 in tensorflow:: 100%|██████████| 603/603 [00:00<00:00, 1950.21it/s]

# %%
  ### This creates a a "labelmap.txt" file with a list of classes the object detection model will detect.
  # %%bash
  cat <<EOF >> /content/labelmap.txt
  close_left
  close_right
  face
  not_yawn
  open_left
  open_right
  yawn
  EOF

# %%
# Create TFRecord files
! wget https://raw.githubusercontent.com/Arijit1080/Licence-Plate-Detection-using-TensorFlow-Lite/main/create_tfrecord.py
# !python3 create_tfrecord.py --csv_input=/content/NewYawn-4/train/_annotations.csv --labelmap=labelmap.txt --image_dir=NewYawn-4/train --output_path=train.tfrecord
# !python3 create_tfrecord.py --csv_input=/content/NewYawn-4/valid/_annotations.csv --labelmap=labelmap.txt --image_dir=/content/NewYawn-4/valid --output_path=val.tfrecord
# Out:
# --2024-04-23 23:09:30--  https://raw.githubusercontent.com/Arijit1080/Licence-Plate-Detection-using-TensorFlow-Lite/main/create_tfrecord.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4414 (4.3K) [text/plain]
# Saving to: ‘create_tfrecord.py’
#
# create_tfrecord.py  100%[===================>]   4.31K  --.-KB/s    in 0s
#
# 2024-04-23 23:09:30 (42.3 MB/s) - ‘create_tfrecord.py’ saved [4414/4414]
#
# Successfully created the TFRecords: /content/train.tfrecord
# Successfully created the TFRecords: /content/val.tfrecord

# %%
train_record_fname = '/content/train.tfrecord'
val_record_fname = '/content/val.tfrecord'
label_map_pbtxt_fname = '/content/labelmap.pbtxt'

# %%
model_name = 'ssd_mobilenet_v2_320x320_coco17_tpu-8'
pretrained_checkpoint = 'ssd_mobilenet_v2_320x320_coco17_tpu-8.tar.gz'
base_pipeline_file = 'ssd_mobilenet_v2_320x320_coco17_tpu-8.config'

# %%
# %mkdir /content/models/mymodel/
# %cd /content/models/mymodel/

import tarfile
download_tar = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/' + pretrained_checkpoint
# !wget {download_tar}
tar = tarfile.open(pretrained_checkpoint)
tar.extractall()
tar.close()

download_config = 'https://raw.githubusercontent.com/tensorflow/models/master/research/object_detection/configs/tf2/' + base_pipeline_file
# !wget {download_config}
# Out:
# mkdir: cannot create directory ‘/content/models/mymodel/’: File exists
# /content/models/mymodel
# --2024-04-23 23:09:41--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_320x320_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 64.233.170.207, 142.251.175.207, 74.125.24.207, ...
# Connecting to download.tensorflow.org (download.tensorflow.org)|64.233.170.207|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46042990 (44M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_320x320_coco17_tpu-8.tar.gz.1’
#
# ssd_mobilenet_v2_32 100%[===================>]  43.91M  14.7MB/s    in 3.0s
#
# 2024-04-23 23:09:44 (14.7 MB/s) - ‘ssd_mobilenet_v2_320x320_coco17_tpu-8.tar.gz.1’ saved [46042990/46042990]
#
# --2024-04-23 23:09:45--  https://raw.githubusercontent.com/tensorflow/models/master/research/object_detection/configs/tf2/ssd_mobilenet_v2_320x320_coco17_tpu-8.config
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4484 (4.4K) [text/plain]
# Saving to: ‘ssd_mobilenet_v2_320x320_coco17_tpu-8.config.1’
#
# ssd_mobilenet_v2_32 100%[===================>]   4.38K  --.-KB/s    in 0s
#
# 2024-04-23 23:09:45 (42.4 MB/s) - ‘ssd_mobilenet_v2_320x320_coco17_tpu-8.config.1’ saved [4484/4484]

# %%
num_steps = 30000
batch_size = 16

# %%
pipeline_fname = '/content/models/mymodel/' + base_pipeline_file
fine_tune_checkpoint = '/content/models/mymodel/' + model_name + '/checkpoint/ckpt-0'

def get_num_classes(pbtxt_fname):
    from object_detection.utils import label_map_util
    label_map = label_map_util.load_labelmap(pbtxt_fname)
    categories = label_map_util.convert_label_map_to_categories(
        label_map, max_num_classes=90, use_display_name=True)
    category_index = label_map_util.create_category_index(categories)
    return len(category_index.keys())
num_classes = get_num_classes(label_map_pbtxt_fname)
print('Total classes:', num_classes)
# Out:
# Total classes: 7

# %%
import re

# %cd /content/models/mymodel
print('writing custom configuration file')

with open(pipeline_fname) as f:
    s = f.read()
with open('pipeline_file.config', 'w') as f:

    s = re.sub('fine_tune_checkpoint: ".*?"',
               'fine_tune_checkpoint: "{}"'.format(fine_tune_checkpoint), s)
    s = re.sub(
        '(input_path: ".*?)(PATH_TO_BE_CONFIGURED/train)(.*?")', 'input_path: "{}"'.format(train_record_fname), s)
    s = re.sub(
        '(input_path: ".*?)(PATH_TO_BE_CONFIGURED/val)(.*?")', 'input_path: "{}"'.format(val_record_fname), s)

    s = re.sub(
        'label_map_path: ".*?"', 'label_map_path: "{}"'.format(label_map_pbtxt_fname), s)

    s = re.sub('batch_size: [0-9]+',
               'batch_size: {}'.format(batch_size), s)

    s = re.sub('num_steps: [0-9]+',
               'num_steps: {}'.format(num_steps), s)

    s = re.sub('num_classes: [0-9]+',
               'num_classes: {}'.format(num_classes), s)

    s = re.sub(
        'fine_tune_checkpoint_type: "classification"', 'fine_tune_checkpoint_type: "{}"'.format('detection'), s)

    s = re.sub('learning_rate_base: .8','learning_rate_base: .08', s)

    s = re.sub('warmup_learning_rate: 0.13333','warmup_learning_rate: .026666', s)

    f.write(s)
# Out:
# /content/models/mymodel
# writing custom configuration file

# %%
# Set the path to the custom config file and the directory to store training checkpoints in
pipeline_file = '/content/models/mymodel/pipeline_file.config'
model_dir = '/content/training/'

# %%
# Run training!
# !python /content/models/research/object_detection/model_main_tf2.py \
    --pipeline_config_path={pipeline_file} \
    --model_dir={model_dir} \
    --alsologtostderr \
    --num_train_steps={num_steps} \
    --sample_1_of_n_eval_examples=1
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.8.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# 2024-04-23 23:09:54.982402: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0423 23:09:54.992192 136340283929728 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 30000
# I0423 23:09:54.998354 136340283929728 config_util.py:552] Maybe overwriting train_steps: 30000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0423 23:09:54.998566 136340283929728 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0423 23:09:55.083098 136340283929728 deprecation.py:337] From /usr/local/lib/python3.10/dist-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['/content/train.tfrecord']
# I0423 23:09:55.107388 136340283929728 dataset_builder.py:162] Reading unweighted datasets: ['/content/train.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['/content/train.tfrecord']
# I0423 23:09:55.107837 136340283929728 dataset_builder.py:79] Reading record datasets for input file: ['/content/train.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# I0423 23:09:55.107990 136340283929728 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0423 23:09:55.108078 136340283929728 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0423 23:09:55.122598 136340283929728 deprecation.py:337] From /usr/local/lib/python3.10/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0423 23:09:55.205720 136340283929728 deprecation.py:337] From /usr/local/lib/python3.10/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0423 23:10:08.303317 136340283929728 deprecation.py:337] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0423 23:10:11.357394 136340283929728 deprecation.py:337] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0423 23:10:14.887149 136340283929728 deprecation.py:337] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# /usr/local/lib/python3.10/dist-packages/keras/backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# I0423 23:10:24.921880 136334450607680 api.py:441] feature_map_spatial_dims: [(19, 19), (10, 10), (5, 5), (3, 3), (2, 2), (1, 1)]
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0423 23:10:28.639828 136334450607680 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0423 23:10:28.640173 136334450607680 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0423 23:10:28.640312 136334450607680 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0423 23:10:28.640453 136334450607680 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0423 23:10:28.640578 136334450607680 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0423 23:10:28.640692 136334450607680 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# I0423 23:10:38.078632 136334450607680 api.py:441] feature_map_spatial_dims: [(19, 19), (10, 10), (5, 5), (3, 3), (2, 2), (1, 1)]
# 2024-04-23 23:10:47.427117: W tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 11.0.194, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0423 23:10:52.192652 136340283929728 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0423 23:10:52.194097 136340283929728 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0423 23:10:52.196691 136340283929728 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0423 23:10:52.197569 136340283929728 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0423 23:10:52.199600 136340283929728 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0423 23:10:52.200426 136340283929728 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0423 23:10:52.202399 136340283929728 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0423 23:10:52.203261 136340283929728 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0423 23:10:52.205269 136340283929728 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0423 23:10:52.206120 136340283929728 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/deprecation.py:616: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0423 23:10:52.777410 136334467393088 deprecation.py:541] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/deprecation.py:616: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I0423 23:10:54.149502 136334467393088 api.py:441] feature_map_spatial_dims: [(19, 19), (10, 10), (5, 5), (3, 3), (2, 2), (1, 1)]
# I0423 23:11:03.297397 136334467393088 api.py:441] feature_map_spatial_dims: [(19, 19), (10, 10), (5, 5), (3, 3), (2, 2), (1, 1)]
# I0423 23:11:11.674797 136334467393088 api.py:441] feature_map_spatial_dims: [(19, 19), (10, 10), (5, 5), (3, 3), (2, 2), (1, 1)]
# I0423 23:11:20.269731 136334467393088 api.py:441] feature_map_spatial_dims: [(19, 19), (10, 10), (5, 5), (3, 3), (2, 2), (1, 1)]
# INFO:tensorflow:Step 100 per-step time 0.711s
# I0423 23:12:03.553108 136340283929728 model_lib_v2.py:705] Step 100 per-step time 0.711s
# INFO:tensorflow:{'Loss/classification_loss': 0.4521897,
#  'Loss/localization_loss': 0.21046072,
#  'Loss/regularization_loss': 0.08640716,
#  'Loss/total_loss': 0.74905765,
#  'learning_rate': 0.029332701}
# I0423 23:12:03.553655 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.4521897,
#  'Loss/localization_loss': 0.21046072,
#  'Loss/regularization_loss': 0.08640716,
#  'Loss/total_loss': 0.74905765,
#  'learning_rate': 0.029332701}
# INFO:tensorflow:Step 200 per-step time 0.226s
# I0423 23:12:26.134651 136340283929728 model_lib_v2.py:705] Step 200 per-step time 0.226s
# INFO:tensorflow:{'Loss/classification_loss': 0.42449465,
#  'Loss/localization_loss': 0.1908847,
#  'Loss/regularization_loss': 0.086562485,
#  'Loss/total_loss': 0.70194185,
#  'learning_rate': 0.0319994}
# I0423 23:12:26.134983 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.42449465,
#  'Loss/localization_loss': 0.1908847,
#  'Loss/regularization_loss': 0.086562485,
#  'Loss/total_loss': 0.70194185,
#  'learning_rate': 0.0319994}
# INFO:tensorflow:Step 300 per-step time 0.227s
# I0423 23:12:48.876494 136340283929728 model_lib_v2.py:705] Step 300 per-step time 0.227s
# INFO:tensorflow:{'Loss/classification_loss': 0.28113294,
#  'Loss/localization_loss': 0.1437931,
#  'Loss/regularization_loss': 0.08669742,
#  'Loss/total_loss': 0.51162344,
#  'learning_rate': 0.0346661}
# I0423 23:12:48.876810 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.28113294,
#  'Loss/localization_loss': 0.1437931,
#  'Loss/regularization_loss': 0.08669742,
#  'Loss/total_loss': 0.51162344,
#  'learning_rate': 0.0346661}
# INFO:tensorflow:Step 400 per-step time 0.229s
# I0423 23:13:11.793507 136340283929728 model_lib_v2.py:705] Step 400 per-step time 0.229s
# INFO:tensorflow:{'Loss/classification_loss': 0.29370484,
#  'Loss/localization_loss': 0.14091314,
#  'Loss/regularization_loss': 0.08679412,
#  'Loss/total_loss': 0.52141213,
#  'learning_rate': 0.0373328}
# I0423 23:13:11.793915 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.29370484,
#  'Loss/localization_loss': 0.14091314,
#  'Loss/regularization_loss': 0.08679412,
#  'Loss/total_loss': 0.52141213,
#  'learning_rate': 0.0373328}
# INFO:tensorflow:Step 500 per-step time 0.229s
# I0423 23:13:34.676241 136340283929728 model_lib_v2.py:705] Step 500 per-step time 0.229s
# INFO:tensorflow:{'Loss/classification_loss': 0.2555681,
#  'Loss/localization_loss': 0.10592361,
#  'Loss/regularization_loss': 0.08690884,
#  'Loss/total_loss': 0.44840053,
#  'learning_rate': 0.0399995}
# I0423 23:13:34.676575 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.2555681,
#  'Loss/localization_loss': 0.10592361,
#  'Loss/regularization_loss': 0.08690884,
#  'Loss/total_loss': 0.44840053,
#  'learning_rate': 0.0399995}
# INFO:tensorflow:Step 600 per-step time 0.235s
# I0423 23:13:58.194626 136340283929728 model_lib_v2.py:705] Step 600 per-step time 0.235s
# INFO:tensorflow:{'Loss/classification_loss': 0.31813622,
#  'Loss/localization_loss': 0.10584352,
#  'Loss/regularization_loss': 0.08702872,
#  'Loss/total_loss': 0.51100844,
#  'learning_rate': 0.0426662}
# I0423 23:13:58.194979 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.31813622,
#  'Loss/localization_loss': 0.10584352,
#  'Loss/regularization_loss': 0.08702872,
#  'Loss/total_loss': 0.51100844,
#  'learning_rate': 0.0426662}
# INFO:tensorflow:Step 700 per-step time 0.224s
# I0423 23:14:20.600707 136340283929728 model_lib_v2.py:705] Step 700 per-step time 0.224s
# INFO:tensorflow:{'Loss/classification_loss': 0.20098715,
#  'Loss/localization_loss': 0.100213684,
#  'Loss/regularization_loss': 0.087164305,
#  'Loss/total_loss': 0.38836515,
#  'learning_rate': 0.0453329}
# I0423 23:14:20.601097 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.20098715,
#  'Loss/localization_loss': 0.100213684,
#  'Loss/regularization_loss': 0.087164305,
#  'Loss/total_loss': 0.38836515,
#  'learning_rate': 0.0453329}
# INFO:tensorflow:Step 800 per-step time 0.231s
# I0423 23:14:43.707780 136340283929728 model_lib_v2.py:705] Step 800 per-step time 0.231s
# INFO:tensorflow:{'Loss/classification_loss': 0.25185966,
#  'Loss/localization_loss': 0.13375686,
#  'Loss/regularization_loss': 0.087303855,
#  'Loss/total_loss': 0.4729204,
#  'learning_rate': 0.047999598}
# I0423 23:14:43.708094 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.25185966,
#  'Loss/localization_loss': 0.13375686,
#  'Loss/regularization_loss': 0.087303855,
#  'Loss/total_loss': 0.4729204,
#  'learning_rate': 0.047999598}
# INFO:tensorflow:Step 900 per-step time 0.234s
# I0423 23:15:07.060451 136340283929728 model_lib_v2.py:705] Step 900 per-step time 0.234s
# INFO:tensorflow:{'Loss/classification_loss': 0.35449326,
#  'Loss/localization_loss': 0.14791684,
#  'Loss/regularization_loss': 0.08743272,
#  'Loss/total_loss': 0.58984286,
#  'learning_rate': 0.050666302}
# I0423 23:15:07.060781 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.35449326,
#  'Loss/localization_loss': 0.14791684,
#  'Loss/regularization_loss': 0.08743272,
#  'Loss/total_loss': 0.58984286,
#  'learning_rate': 0.050666302}
# INFO:tensorflow:Step 1000 per-step time 0.227s
# I0423 23:15:29.770624 136340283929728 model_lib_v2.py:705] Step 1000 per-step time 0.227s
# INFO:tensorflow:{'Loss/classification_loss': 0.21345627,
#  'Loss/localization_loss': 0.090343766,
#  'Loss/regularization_loss': 0.08763816,
#  'Loss/total_loss': 0.39143822,
#  'learning_rate': 0.053333}
# I0423 23:15:29.770995 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.21345627,
#  'Loss/localization_loss': 0.090343766,
#  'Loss/regularization_loss': 0.08763816,
#  'Loss/total_loss': 0.39143822,
#  'learning_rate': 0.053333}
# INFO:tensorflow:Step 1100 per-step time 0.236s
# I0423 23:15:53.331045 136340283929728 model_lib_v2.py:705] Step 1100 per-step time 0.236s
# INFO:tensorflow:{'Loss/classification_loss': 0.39974767,
#  'Loss/localization_loss': 0.14076854,
#  'Loss/regularization_loss': 0.08776232,
#  'Loss/total_loss': 0.6282785,
#  'learning_rate': 0.0559997}
# I0423 23:15:53.331394 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.39974767,
#  'Loss/localization_loss': 0.14076854,
#  'Loss/regularization_loss': 0.08776232,
#  'Loss/total_loss': 0.6282785,
#  'learning_rate': 0.0559997}
# INFO:tensorflow:Step 1200 per-step time 0.228s
# I0423 23:16:16.168198 136340283929728 model_lib_v2.py:705] Step 1200 per-step time 0.228s
# INFO:tensorflow:{'Loss/classification_loss': 0.20183758,
#  'Loss/localization_loss': 0.09249853,
#  'Loss/regularization_loss': 0.08800829,
#  'Loss/total_loss': 0.3823444,
#  'learning_rate': 0.0586664}
# I0423 23:16:16.168578 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.20183758,
#  'Loss/localization_loss': 0.09249853,
#  'Loss/regularization_loss': 0.08800829,
#  'Loss/total_loss': 0.3823444,
#  'learning_rate': 0.0586664}
# INFO:tensorflow:Step 1300 per-step time 0.228s
# I0423 23:16:39.001197 136340283929728 model_lib_v2.py:705] Step 1300 per-step time 0.228s
# INFO:tensorflow:{'Loss/classification_loss': 0.2931714,
#  'Loss/localization_loss': 0.10305039,
#  'Loss/regularization_loss': 0.08825234,
#  'Loss/total_loss': 0.48447412,
#  'learning_rate': 0.0613331}
# I0423 23:16:39.001638 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.2931714,
#  'Loss/localization_loss': 0.10305039,
#  'Loss/regularization_loss': 0.08825234,
#  'Loss/total_loss': 0.48447412,
#  'learning_rate': 0.0613331}
# INFO:tensorflow:Step 1400 per-step time 0.234s
# I0423 23:17:02.385723 136340283929728 model_lib_v2.py:705] Step 1400 per-step time 0.234s
# INFO:tensorflow:{'Loss/classification_loss': 0.20986032,
#  'Loss/localization_loss': 0.08475162,
#  'Loss/regularization_loss': 0.08848547,
#  'Loss/total_loss': 0.3830974,
#  'learning_rate': 0.0639998}
# I0423 23:17:02.386033 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.20986032,
#  'Loss/localization_loss': 0.08475162,
#  'Loss/regularization_loss': 0.08848547,
#  'Loss/total_loss': 0.3830974,
#  'learning_rate': 0.0639998}
# INFO:tensorflow:Step 1500 per-step time 0.230s
# I0423 23:17:25.340172 136340283929728 model_lib_v2.py:705] Step 1500 per-step time 0.230s
# INFO:tensorflow:{'Loss/classification_loss': 0.3171847,
#  'Loss/localization_loss': 0.11553965,
#  'Loss/regularization_loss': 0.08864889,
#  'Loss/total_loss': 0.5213732,
#  'learning_rate': 0.0666665}
# I0423 23:17:25.340564 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.3171847,
#  'Loss/localization_loss': 0.11553965,
#  'Loss/regularization_loss': 0.08864889,
#  'Loss/total_loss': 0.5213732,
#  'learning_rate': 0.0666665}
# INFO:tensorflow:Step 1600 per-step time 0.225s
# I0423 23:17:47.831899 136340283929728 model_lib_v2.py:705] Step 1600 per-step time 0.225s
# INFO:tensorflow:{'Loss/classification_loss': 0.22358996,
#  'Loss/localization_loss': 0.09089582,
#  'Loss/regularization_loss': 0.08895186,
#  'Loss/total_loss': 0.40343764,
#  'learning_rate': 0.069333196}
# I0423 23:17:47.832267 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.22358996,
#  'Loss/localization_loss': 0.09089582,
#  'Loss/regularization_loss': 0.08895186,
#  'Loss/total_loss': 0.40343764,
#  'learning_rate': 0.069333196}
# INFO:tensorflow:Step 1700 per-step time 0.230s
# I0423 23:18:10.840056 136340283929728 model_lib_v2.py:705] Step 1700 per-step time 0.230s
# INFO:tensorflow:{'Loss/classification_loss': 0.2971133,
#  'Loss/localization_loss': 0.12764326,
#  'Loss/regularization_loss': 0.089120544,
#  'Loss/total_loss': 0.5138771,
#  'learning_rate': 0.0719999}
# I0423 23:18:10.840411 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.2971133,
#  'Loss/localization_loss': 0.12764326,
#  'Loss/regularization_loss': 0.089120544,
#  'Loss/total_loss': 0.5138771,
#  'learning_rate': 0.0719999}
# INFO:tensorflow:Step 1800 per-step time 0.230s
# I0423 23:18:33.818361 136340283929728 model_lib_v2.py:705] Step 1800 per-step time 0.230s
# INFO:tensorflow:{'Loss/classification_loss': 0.32923454,
#  'Loss/localization_loss': 0.11121405,
#  'Loss/regularization_loss': 0.08954339,
#  'Loss/total_loss': 0.529992,
#  'learning_rate': 0.074666604}
# I0423 23:18:33.818693 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.32923454,
#  'Loss/localization_loss': 0.11121405,
#  'Loss/regularization_loss': 0.08954339,
#  'Loss/total_loss': 0.529992,
#  'learning_rate': 0.074666604}
# INFO:tensorflow:Step 1900 per-step time 0.227s
# I0423 23:18:56.539953 136340283929728 model_lib_v2.py:705] Step 1900 per-step time 0.227s
# INFO:tensorflow:{'Loss/classification_loss': 0.2693525,
#  'Loss/localization_loss': 0.13517167,
#  'Loss/regularization_loss': 0.089937024,
#  'Loss/total_loss': 0.49446118,
#  'learning_rate': 0.0773333}
# I0423 23:18:56.540319 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.2693525,
#  'Loss/localization_loss': 0.13517167,
#  'Loss/regularization_loss': 0.089937024,
#  'Loss/total_loss': 0.49446118,
#  'learning_rate': 0.0773333}
# INFO:tensorflow:Step 2000 per-step time 0.228s
# I0423 23:19:19.374982 136340283929728 model_lib_v2.py:705] Step 2000 per-step time 0.228s
# INFO:tensorflow:{'Loss/classification_loss': 0.19047804,
#  'Loss/localization_loss': 0.10740277,
#  'Loss/regularization_loss': 0.09017951,
#  'Loss/total_loss': 0.38806033,
#  'learning_rate': 0.08}
# I0423 23:19:19.375300 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.19047804,
#  'Loss/localization_loss': 0.10740277,
#  'Loss/regularization_loss': 0.09017951,
#  'Loss/total_loss': 0.38806033,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 2100 per-step time 0.236s
# I0423 23:19:42.933853 136340283929728 model_lib_v2.py:705] Step 2100 per-step time 0.236s
# INFO:tensorflow:{'Loss/classification_loss': 0.23660353,
#  'Loss/localization_loss': 0.109547,
#  'Loss/regularization_loss': 0.09037533,
#  'Loss/total_loss': 0.43652585,
#  'learning_rate': 0.07999914}
# I0423 23:19:42.934163 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.23660353,
#  'Loss/localization_loss': 0.109547,
#  'Loss/regularization_loss': 0.09037533,
#  'Loss/total_loss': 0.43652585,
#  'learning_rate': 0.07999914}
# INFO:tensorflow:Step 2200 per-step time 0.233s
# I0423 23:20:06.228316 136340283929728 model_lib_v2.py:705] Step 2200 per-step time 0.233s
# INFO:tensorflow:{'Loss/classification_loss': 0.27425027,
#  'Loss/localization_loss': 0.15294181,
#  'Loss/regularization_loss': 0.09064288,
#  'Loss/total_loss': 0.51783496,
#  'learning_rate': 0.07999657}
# I0423 23:20:06.228693 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.27425027,
#  'Loss/localization_loss': 0.15294181,
#  'Loss/regularization_loss': 0.09064288,
#  'Loss/total_loss': 0.51783496,
#  'learning_rate': 0.07999657}
# INFO:tensorflow:Step 2300 per-step time 0.232s
# I0423 23:20:29.418314 136340283929728 model_lib_v2.py:705] Step 2300 per-step time 0.232s
# INFO:tensorflow:{'Loss/classification_loss': 0.27667654,
#  'Loss/localization_loss': 0.0879467,
#  'Loss/regularization_loss': 0.09097986,
#  'Loss/total_loss': 0.45560312,
#  'learning_rate': 0.07999229}
# I0423 23:20:29.418655 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.27667654,
#  'Loss/localization_loss': 0.0879467,
#  'Loss/regularization_loss': 0.09097986,
#  'Loss/total_loss': 0.45560312,
#  'learning_rate': 0.07999229}
# INFO:tensorflow:Step 2400 per-step time 0.233s
# I0423 23:20:52.751014 136340283929728 model_lib_v2.py:705] Step 2400 per-step time 0.233s
# INFO:tensorflow:{'Loss/classification_loss': 0.19099782,
#  'Loss/localization_loss': 0.09004739,
#  'Loss/regularization_loss': 0.09122603,
#  'Loss/total_loss': 0.37227124,
#  'learning_rate': 0.0799863}
# I0423 23:20:52.751374 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.19099782,
#  'Loss/localization_loss': 0.09004739,
#  'Loss/regularization_loss': 0.09122603,
#  'Loss/total_loss': 0.37227124,
#  'learning_rate': 0.0799863}
# INFO:tensorflow:Step 2500 per-step time 0.224s
# I0423 23:21:15.206410 136340283929728 model_lib_v2.py:705] Step 2500 per-step time 0.224s
# INFO:tensorflow:{'Loss/classification_loss': 0.1702848,
#  'Loss/localization_loss': 0.10759655,
#  'Loss/regularization_loss': 0.09145927,
#  'Loss/total_loss': 0.3693406,
#  'learning_rate': 0.07997858}
# I0423 23:21:15.206875 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.1702848,
#  'Loss/localization_loss': 0.10759655,
#  'Loss/regularization_loss': 0.09145927,
#  'Loss/total_loss': 0.3693406,
#  'learning_rate': 0.07997858}
# INFO:tensorflow:Step 2600 per-step time 0.230s
# I0423 23:21:38.224127 136340283929728 model_lib_v2.py:705] Step 2600 per-step time 0.230s
# INFO:tensorflow:{'Loss/classification_loss': 0.199954,
#  'Loss/localization_loss': 0.087816454,
#  'Loss/regularization_loss': 0.09151529,
#  'Loss/total_loss': 0.37928575,
#  'learning_rate': 0.07996915}
# I0423 23:21:38.224501 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.199954,
#  'Loss/localization_loss': 0.087816454,
#  'Loss/regularization_loss': 0.09151529,
#  'Loss/total_loss': 0.37928575,
#  'learning_rate': 0.07996915}
# INFO:tensorflow:Step 2700 per-step time 0.233s
# I0423 23:22:01.553555 136340283929728 model_lib_v2.py:705] Step 2700 per-step time 0.233s
# INFO:tensorflow:{'Loss/classification_loss': 0.28871495,
#  'Loss/localization_loss': 0.09112912,
#  'Loss/regularization_loss': 0.09166015,
#  'Loss/total_loss': 0.4715042,
#  'learning_rate': 0.07995803}
# I0423 23:22:01.553946 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.28871495,
#  'Loss/localization_loss': 0.09112912,
#  'Loss/regularization_loss': 0.09166015,
#  'Loss/total_loss': 0.4715042,
#  'learning_rate': 0.07995803}
# INFO:tensorflow:Step 2800 per-step time 0.227s
# I0423 23:22:24.304829 136340283929728 model_lib_v2.py:705] Step 2800 per-step time 0.227s
# INFO:tensorflow:{'Loss/classification_loss': 0.17008194,
#  'Loss/localization_loss': 0.09944253,
#  'Loss/regularization_loss': 0.091787554,
#  'Loss/total_loss': 0.361312,
#  'learning_rate': 0.079945184}
# I0423 23:22:24.305198 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.17008194,
#  'Loss/localization_loss': 0.09944253,
#  'Loss/regularization_loss': 0.091787554,
#  'Loss/total_loss': 0.361312,
#  'learning_rate': 0.079945184}
# INFO:tensorflow:Step 2900 per-step time 0.231s
# I0423 23:22:47.406601 136340283929728 model_lib_v2.py:705] Step 2900 per-step time 0.231s
# INFO:tensorflow:{'Loss/classification_loss': 0.2292092,
#  'Loss/localization_loss': 0.09243168,
#  'Loss/regularization_loss': 0.09183282,
#  'Loss/total_loss': 0.4134737,
#  'learning_rate': 0.079930626}
# I0423 23:22:47.406936 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.2292092,
#  'Loss/localization_loss': 0.09243168,
#  'Loss/regularization_loss': 0.09183282,
#  'Loss/total_loss': 0.4134737,
#  'learning_rate': 0.079930626}
# INFO:tensorflow:Step 3000 per-step time 0.235s
# I0423 23:23:10.927069 136340283929728 model_lib_v2.py:705] Step 3000 per-step time 0.235s
# INFO:tensorflow:{'Loss/classification_loss': 0.21066585,
#  'Loss/localization_loss': 0.08294615,
#  'Loss/regularization_loss': 0.09194975,
#  'Loss/total_loss': 0.38556176,
#  'learning_rate': 0.07991436}
# I0423 23:23:10.927413 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.21066585,
#  'Loss/localization_loss': 0.08294615,
#  'Loss/regularization_loss': 0.09194975,
#  'Loss/total_loss': 0.38556176,
#  'learning_rate': 0.07991436}
# INFO:tensorflow:Step 3100 per-step time 0.236s
# I0423 23:23:34.527682 136340283929728 model_lib_v2.py:705] Step 3100 per-step time 0.236s
# INFO:tensorflow:{'Loss/classification_loss': 0.17816749,
#  'Loss/localization_loss': 0.06971232,
#  'Loss/regularization_loss': 0.0920986,
#  'Loss/total_loss': 0.3399784,
#  'learning_rate': 0.079896376}
# I0423 23:23:34.528089 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.17816749,
#  'Loss/localization_loss': 0.06971232,
#  'Loss/regularization_loss': 0.0920986,
#  'Loss/total_loss': 0.3399784,
#  'learning_rate': 0.079896376}
# INFO:tensorflow:Step 3200 per-step time 0.230s
# I0423 23:23:57.571291 136340283929728 model_lib_v2.py:705] Step 3200 per-step time 0.230s
# INFO:tensorflow:{'Loss/classification_loss': 0.17074944,
#  'Loss/localization_loss': 0.09592864,
#  'Loss/regularization_loss': 0.09222706,
#  'Loss/total_loss': 0.35890514,
#  'learning_rate': 0.07987669}
# I0423 23:23:57.571649 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.17074944,
#  'Loss/localization_loss': 0.09592864,
#  'Loss/regularization_loss': 0.09222706,
#  'Loss/total_loss': 0.35890514,
#  'learning_rate': 0.07987669}
# INFO:tensorflow:Step 3300 per-step time 0.232s
# I0423 23:24:20.757205 136340283929728 model_lib_v2.py:705] Step 3300 per-step time 0.232s
# INFO:tensorflow:{'Loss/classification_loss': 0.22139008,
#  'Loss/localization_loss': 0.09431515,
#  'Loss/regularization_loss': 0.09229631,
#  'Loss/total_loss': 0.40800154,
#  'learning_rate': 0.0798553}
# I0423 23:24:20.757584 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.22139008,
#  'Loss/localization_loss': 0.09431515,
#  'Loss/regularization_loss': 0.09229631,
#  'Loss/total_loss': 0.40800154,
#  'learning_rate': 0.0798553}
# INFO:tensorflow:Step 3400 per-step time 0.229s
# I0423 23:24:43.695373 136340283929728 model_lib_v2.py:705] Step 3400 per-step time 0.229s
# INFO:tensorflow:{'Loss/classification_loss': 0.18069395,
#  'Loss/localization_loss': 0.08722458,
#  'Loss/regularization_loss': 0.092374116,
#  'Loss/total_loss': 0.36029264,
#  'learning_rate': 0.079832196}
# I0423 23:24:43.695757 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.18069395,
#  'Loss/localization_loss': 0.08722458,
#  'Loss/regularization_loss': 0.092374116,
#  'Loss/total_loss': 0.36029264,
#  'learning_rate': 0.079832196}
# INFO:tensorflow:Step 3500 per-step time 0.231s
# I0423 23:25:06.767645 136340283929728 model_lib_v2.py:705] Step 3500 per-step time 0.231s
# INFO:tensorflow:{'Loss/classification_loss': 0.17891999,
#  'Loss/localization_loss': 0.108584024,
#  'Loss/regularization_loss': 0.09246196,
#  'Loss/total_loss': 0.37996596,
#  'learning_rate': 0.079807386}
# I0423 23:25:06.767964 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.17891999,
#  'Loss/localization_loss': 0.108584024,
#  'Loss/regularization_loss': 0.09246196,
#  'Loss/total_loss': 0.37996596,
#  'learning_rate': 0.079807386}
# INFO:tensorflow:Step 3600 per-step time 0.232s
# I0423 23:25:30.006667 136340283929728 model_lib_v2.py:705] Step 3600 per-step time 0.232s
# INFO:tensorflow:{'Loss/classification_loss': 0.17446844,
#  'Loss/localization_loss': 0.0777423,
#  'Loss/regularization_loss': 0.09255,
#  'Loss/total_loss': 0.34476075,
#  'learning_rate': 0.07978087}
# I0423 23:25:30.006987 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.17446844,
#  'Loss/localization_loss': 0.0777423,
#  'Loss/regularization_loss': 0.09255,
#  'Loss/total_loss': 0.34476075,
#  'learning_rate': 0.07978087}
# INFO:tensorflow:Step 3700 per-step time 0.230s
# I0423 23:25:53.055315 136340283929728 model_lib_v2.py:705] Step 3700 per-step time 0.230s
# INFO:tensorflow:{'Loss/classification_loss': 0.17406009,
#  'Loss/localization_loss': 0.06452707,
#  'Loss/regularization_loss': 0.09253485,
#  'Loss/total_loss': 0.331122,
#  'learning_rate': 0.079752654}
# I0423 23:25:53.055707 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.17406009,
#  'Loss/localization_loss': 0.06452707,
#  'Loss/regularization_loss': 0.09253485,
#  'Loss/total_loss': 0.331122,
#  'learning_rate': 0.079752654}
# INFO:tensorflow:Step 3800 per-step time 0.234s
# I0423 23:26:16.452327 136340283929728 model_lib_v2.py:705] Step 3800 per-step time 0.234s
# INFO:tensorflow:{'Loss/classification_loss': 0.17537327,
#  'Loss/localization_loss': 0.08318664,
#  'Loss/regularization_loss': 0.09259549,
#  'Loss/total_loss': 0.3511554,
#  'learning_rate': 0.07972274}
# I0423 23:26:16.452666 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.17537327,
#  'Loss/localization_loss': 0.08318664,
#  'Loss/regularization_loss': 0.09259549,
#  'Loss/total_loss': 0.3511554,
#  'learning_rate': 0.07972274}
# INFO:tensorflow:Step 3900 per-step time 0.231s
# I0423 23:26:39.560610 136340283929728 model_lib_v2.py:705] Step 3900 per-step time 0.231s
# INFO:tensorflow:{'Loss/classification_loss': 0.1746784,
#  'Loss/localization_loss': 0.08227006,
#  'Loss/regularization_loss': 0.09266392,
#  'Loss/total_loss': 0.34961239,
#  'learning_rate': 0.07969111}
# I0423 23:26:39.560918 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.1746784,
#  'Loss/localization_loss': 0.08227006,
#  'Loss/regularization_loss': 0.09266392,
#  'Loss/total_loss': 0.34961239,
#  'learning_rate': 0.07969111}
# INFO:tensorflow:Step 4000 per-step time 0.228s
# I0423 23:27:02.372332 136340283929728 model_lib_v2.py:705] Step 4000 per-step time 0.228s
# INFO:tensorflow:{'Loss/classification_loss': 0.1875296,
#  'Loss/localization_loss': 0.097452834,
#  'Loss/regularization_loss': 0.0927,
#  'Loss/total_loss': 0.37768245,
#  'learning_rate': 0.07965779}
# I0423 23:27:02.372703 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.1875296,
#  'Loss/localization_loss': 0.097452834,
#  'Loss/regularization_loss': 0.0927,
#  'Loss/total_loss': 0.37768245,
#  'learning_rate': 0.07965779}
# INFO:tensorflow:Step 4100 per-step time 0.235s
# I0423 23:27:25.888781 136340283929728 model_lib_v2.py:705] Step 4100 per-step time 0.235s
# INFO:tensorflow:{'Loss/classification_loss': 0.17001578,
#  'Loss/localization_loss': 0.079814106,
#  'Loss/regularization_loss': 0.09293435,
#  'Loss/total_loss': 0.34276423,
#  'learning_rate': 0.079622775}
# I0423 23:27:25.889102 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.17001578,
#  'Loss/localization_loss': 0.079814106,
#  'Loss/regularization_loss': 0.09293435,
#  'Loss/total_loss': 0.34276423,
#  'learning_rate': 0.079622775}
# INFO:tensorflow:Step 4200 per-step time 0.232s
# I0423 23:27:49.069533 136340283929728 model_lib_v2.py:705] Step 4200 per-step time 0.232s
# INFO:tensorflow:{'Loss/classification_loss': 0.16512021,
#  'Loss/localization_loss': 0.0769954,
#  'Loss/regularization_loss': 0.09299886,
#  'Loss/total_loss': 0.33511448,
#  'learning_rate': 0.07958606}
# I0423 23:27:49.069901 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.16512021,
#  'Loss/localization_loss': 0.0769954,
#  'Loss/regularization_loss': 0.09299886,
#  'Loss/total_loss': 0.33511448,
#  'learning_rate': 0.07958606}
# INFO:tensorflow:Step 4300 per-step time 0.229s
# I0423 23:28:11.975810 136340283929728 model_lib_v2.py:705] Step 4300 per-step time 0.229s
# INFO:tensorflow:{'Loss/classification_loss': 0.17375666,
#  'Loss/localization_loss': 0.09007632,
#  'Loss/regularization_loss': 0.09307992,
#  'Loss/total_loss': 0.3569129,
#  'learning_rate': 0.07954764}
# I0423 23:28:11.976138 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.17375666,
#  'Loss/localization_loss': 0.09007632,
#  'Loss/regularization_loss': 0.09307992,
#  'Loss/total_loss': 0.3569129,
#  'learning_rate': 0.07954764}
# INFO:tensorflow:Step 4400 per-step time 0.226s
# I0423 23:28:34.523950 136340283929728 model_lib_v2.py:705] Step 4400 per-step time 0.226s
# INFO:tensorflow:{'Loss/classification_loss': 0.14156061,
#  'Loss/localization_loss': 0.054953057,
#  'Loss/regularization_loss': 0.093218595,
#  'Loss/total_loss': 0.28973228,
#  'learning_rate': 0.07950753}
# I0423 23:28:34.524291 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.14156061,
#  'Loss/localization_loss': 0.054953057,
#  'Loss/regularization_loss': 0.093218595,
#  'Loss/total_loss': 0.28973228,
#  'learning_rate': 0.07950753}
# INFO:tensorflow:Step 4500 per-step time 0.230s
# I0423 23:28:57.565199 136340283929728 model_lib_v2.py:705] Step 4500 per-step time 0.230s
# INFO:tensorflow:{'Loss/classification_loss': 0.21947938,
#  'Loss/localization_loss': 0.0729324,
#  'Loss/regularization_loss': 0.093188,
#  'Loss/total_loss': 0.3855998,
#  'learning_rate': 0.07946573}
# I0423 23:28:57.565583 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.21947938,
#  'Loss/localization_loss': 0.0729324,
#  'Loss/regularization_loss': 0.093188,
#  'Loss/total_loss': 0.3855998,
#  'learning_rate': 0.07946573}
# INFO:tensorflow:Step 4600 per-step time 0.230s
# I0423 23:29:20.547057 136340283929728 model_lib_v2.py:705] Step 4600 per-step time 0.230s
# INFO:tensorflow:{'Loss/classification_loss': 0.19716436,
#  'Loss/localization_loss': 0.06885124,
#  'Loss/regularization_loss': 0.09310227,
#  'Loss/total_loss': 0.35911787,
#  'learning_rate': 0.07942224}
# I0423 23:29:20.547404 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.19716436,
#  'Loss/localization_loss': 0.06885124,
#  'Loss/regularization_loss': 0.09310227,
#  'Loss/total_loss': 0.35911787,
#  'learning_rate': 0.07942224}
# INFO:tensorflow:Step 4700 per-step time 0.234s
# I0423 23:29:43.922989 136340283929728 model_lib_v2.py:705] Step 4700 per-step time 0.234s
# INFO:tensorflow:{'Loss/classification_loss': 0.1771162,
#  'Loss/localization_loss': 0.07490926,
#  'Loss/regularization_loss': 0.093058385,
#  'Loss/total_loss': 0.34508383,
#  'learning_rate': 0.079377055}
# I0423 23:29:43.923341 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.1771162,
#  'Loss/localization_loss': 0.07490926,
#  'Loss/regularization_loss': 0.093058385,
#  'Loss/total_loss': 0.34508383,
#  'learning_rate': 0.079377055}
# INFO:tensorflow:Step 4800 per-step time 0.233s
# I0423 23:30:07.194114 136340283929728 model_lib_v2.py:705] Step 4800 per-step time 0.233s
# INFO:tensorflow:{'Loss/classification_loss': 0.14481255,
#  'Loss/localization_loss': 0.0715892,
#  'Loss/regularization_loss': 0.092996255,
#  'Loss/total_loss': 0.309398,
#  'learning_rate': 0.07933019}
# I0423 23:30:07.194467 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.14481255,
#  'Loss/localization_loss': 0.0715892,
#  'Loss/regularization_loss': 0.092996255,
#  'Loss/total_loss': 0.309398,
#  'learning_rate': 0.07933019}
# INFO:tensorflow:Step 4900 per-step time 0.228s
# I0423 23:30:30.018183 136340283929728 model_lib_v2.py:705] Step 4900 per-step time 0.228s
# INFO:tensorflow:{'Loss/classification_loss': 0.19495964,
#  'Loss/localization_loss': 0.11416153,
#  'Loss/regularization_loss': 0.093032666,
#  'Loss/total_loss': 0.40215382,
#  'learning_rate': 0.07928164}
# I0423 23:30:30.018606 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.19495964,
#  'Loss/localization_loss': 0.11416153,
#  'Loss/regularization_loss': 0.093032666,
#  'Loss/total_loss': 0.40215382,
#  'learning_rate': 0.07928164}
# INFO:tensorflow:Step 5000 per-step time 0.231s
# I0423 23:30:53.142916 136340283929728 model_lib_v2.py:705] Step 5000 per-step time 0.231s
# INFO:tensorflow:{'Loss/classification_loss': 0.160101,
#  'Loss/localization_loss': 0.051640753,
#  'Loss/regularization_loss': 0.09305662,
#  'Loss/total_loss': 0.30479836,
#  'learning_rate': 0.07923141}
# I0423 23:30:53.143211 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.160101,
#  'Loss/localization_loss': 0.051640753,
#  'Loss/regularization_loss': 0.09305662,
#  'Loss/total_loss': 0.30479836,
#  'learning_rate': 0.07923141}
# INFO:tensorflow:Step 5100 per-step time 0.233s
# I0423 23:31:16.477990 136340283929728 model_lib_v2.py:705] Step 5100 per-step time 0.233s
# INFO:tensorflow:{'Loss/classification_loss': 0.20519523,
#  'Loss/localization_loss': 0.060467336,
#  'Loss/regularization_loss': 0.09300667,
#  'Loss/total_loss': 0.35866925,
#  'learning_rate': 0.079179496}
# I0423 23:31:16.478325 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.20519523,
#  'Loss/localization_loss': 0.060467336,
#  'Loss/regularization_loss': 0.09300667,
#  'Loss/total_loss': 0.35866925,
#  'learning_rate': 0.079179496}
# INFO:tensorflow:Step 5200 per-step time 0.227s
# I0423 23:31:39.130428 136340283929728 model_lib_v2.py:705] Step 5200 per-step time 0.227s
# INFO:tensorflow:{'Loss/classification_loss': 0.18065329,
#  'Loss/localization_loss': 0.07571909,
#  'Loss/regularization_loss': 0.093006104,
#  'Loss/total_loss': 0.3493785,
#  'learning_rate': 0.0791259}
# I0423 23:31:39.130799 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.18065329,
#  'Loss/localization_loss': 0.07571909,
#  'Loss/regularization_loss': 0.093006104,
#  'Loss/total_loss': 0.3493785,
#  'learning_rate': 0.0791259}
# INFO:tensorflow:Step 5300 per-step time 0.229s
# I0423 23:32:02.065735 136340283929728 model_lib_v2.py:705] Step 5300 per-step time 0.229s
# INFO:tensorflow:{'Loss/classification_loss': 0.17498383,
#  'Loss/localization_loss': 0.078419514,
#  'Loss/regularization_loss': 0.09296388,
#  'Loss/total_loss': 0.3463672,
#  'learning_rate': 0.079070635}
# I0423 23:32:02.066122 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.17498383,
#  'Loss/localization_loss': 0.078419514,
#  'Loss/regularization_loss': 0.09296388,
#  'Loss/total_loss': 0.3463672,
#  'learning_rate': 0.079070635}
# INFO:tensorflow:Step 5400 per-step time 0.235s
# I0423 23:32:25.570953 136340283929728 model_lib_v2.py:705] Step 5400 per-step time 0.235s
# INFO:tensorflow:{'Loss/classification_loss': 0.17737973,
#  'Loss/localization_loss': 0.06906918,
#  'Loss/regularization_loss': 0.09292473,
#  'Loss/total_loss': 0.33937365,
#  'learning_rate': 0.07901369}
# I0423 23:32:25.571299 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.17737973,
#  'Loss/localization_loss': 0.06906918,
#  'Loss/regularization_loss': 0.09292473,
#  'Loss/total_loss': 0.33937365,
#  'learning_rate': 0.07901369}
# INFO:tensorflow:Step 5500 per-step time 0.232s
# I0423 23:32:48.806749 136340283929728 model_lib_v2.py:705] Step 5500 per-step time 0.232s
# INFO:tensorflow:{'Loss/classification_loss': 0.19570024,
#  'Loss/localization_loss': 0.07294695,
#  'Loss/regularization_loss': 0.09290159,
#  'Loss/total_loss': 0.36154878,
#  'learning_rate': 0.07895508}
# I0423 23:32:48.807166 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.19570024,
#  'Loss/localization_loss': 0.07294695,
#  'Loss/regularization_loss': 0.09290159,
#  'Loss/total_loss': 0.36154878,
#  'learning_rate': 0.07895508}
# INFO:tensorflow:Step 5600 per-step time 0.231s
# I0423 23:33:11.945011 136340283929728 model_lib_v2.py:705] Step 5600 per-step time 0.231s
# INFO:tensorflow:{'Loss/classification_loss': 0.1511887,
#  'Loss/localization_loss': 0.07072826,
#  'Loss/regularization_loss': 0.09282468,
#  'Loss/total_loss': 0.31474164,
#  'learning_rate': 0.078894794}
# I0423 23:33:11.945339 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.1511887,
#  'Loss/localization_loss': 0.07072826,
#  'Loss/regularization_loss': 0.09282468,
#  'Loss/total_loss': 0.31474164,
#  'learning_rate': 0.078894794}
# INFO:tensorflow:Step 5700 per-step time 0.231s
# I0423 23:33:34.998243 136340283929728 model_lib_v2.py:705] Step 5700 per-step time 0.231s
# INFO:tensorflow:{'Loss/classification_loss': 0.24518238,
#  'Loss/localization_loss': 0.12962002,
#  'Loss/regularization_loss': 0.092854224,
#  'Loss/total_loss': 0.46765664,
#  'learning_rate': 0.07883284}
# I0423 23:33:34.998579 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.24518238,
#  'Loss/localization_loss': 0.12962002,
#  'Loss/regularization_loss': 0.092854224,
#  'Loss/total_loss': 0.46765664,
#  'learning_rate': 0.07883284}
# INFO:tensorflow:Step 5800 per-step time 0.229s
# I0423 23:33:57.893280 136340283929728 model_lib_v2.py:705] Step 5800 per-step time 0.229s
# INFO:tensorflow:{'Loss/classification_loss': 0.1639662,
#  'Loss/localization_loss': 0.08972374,
#  'Loss/regularization_loss': 0.092957,
#  'Loss/total_loss': 0.34664693,
#  'learning_rate': 0.07876924}
# I0423 23:33:57.893678 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.1639662,
#  'Loss/localization_loss': 0.08972374,
#  'Loss/regularization_loss': 0.092957,
#  'Loss/total_loss': 0.34664693,
#  'learning_rate': 0.07876924}
# INFO:tensorflow:Step 5900 per-step time 0.232s
# I0423 23:34:21.134057 136340283929728 model_lib_v2.py:705] Step 5900 per-step time 0.232s
# INFO:tensorflow:{'Loss/classification_loss': 0.22514622,
#  'Loss/localization_loss': 0.101501115,
#  'Loss/regularization_loss': 0.09283914,
#  'Loss/total_loss': 0.41948646,
#  'learning_rate': 0.07870396}
# I0423 23:34:21.134377 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.22514622,
#  'Loss/localization_loss': 0.101501115,
#  'Loss/regularization_loss': 0.09283914,
#  'Loss/total_loss': 0.41948646,
#  'learning_rate': 0.07870396}
# INFO:tensorflow:Step 6000 per-step time 0.229s
# I0423 23:34:44.050763 136340283929728 model_lib_v2.py:705] Step 6000 per-step time 0.229s
# INFO:tensorflow:{'Loss/classification_loss': 0.16672233,
#  'Loss/localization_loss': 0.08165614,
#  'Loss/regularization_loss': 0.09282132,
#  'Loss/total_loss': 0.3411998,
#  'learning_rate': 0.07863703}
# I0423 23:34:44.051084 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.16672233,
# ...
#  'learning_rate': 0.03660071}
# I0424 00:56:36.443178 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.10673308,
#  'Loss/localization_loss': 0.031018078,
#  'Loss/regularization_loss': 0.072357066,
#  'Loss/total_loss': 0.21010822,
#  'learning_rate': 0.03660071}
# INFO:tensorflow:Step 27400 per-step time 0.233s
# I0424 00:56:59.770254 136340283929728 model_lib_v2.py:705] Step 27400 per-step time 0.233s
# INFO:tensorflow:{'Loss/classification_loss': 0.094853625,
#  'Loss/localization_loss': 0.025191968,
#  'Loss/regularization_loss': 0.072251186,
#  'Loss/total_loss': 0.19229677,
#  'learning_rate': 0.036339935}
# I0424 00:56:59.770654 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.094853625,
#  'Loss/localization_loss': 0.025191968,
#  'Loss/regularization_loss': 0.072251186,
#  'Loss/total_loss': 0.19229677,
#  'learning_rate': 0.036339935}
# INFO:tensorflow:Step 27500 per-step time 0.226s
# I0424 00:57:22.373092 136340283929728 model_lib_v2.py:705] Step 27500 per-step time 0.226s
# INFO:tensorflow:{'Loss/classification_loss': 0.15480067,
#  'Loss/localization_loss': 0.035855204,
#  'Loss/regularization_loss': 0.07216011,
#  'Loss/total_loss': 0.26281598,
#  'learning_rate': 0.03607931}
# I0424 00:57:22.373461 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.15480067,
#  'Loss/localization_loss': 0.035855204,
#  'Loss/regularization_loss': 0.07216011,
#  'Loss/total_loss': 0.26281598,
#  'learning_rate': 0.03607931}
# INFO:tensorflow:Step 27600 per-step time 0.229s
# I0424 00:57:45.308762 136340283929728 model_lib_v2.py:705] Step 27600 per-step time 0.229s
# INFO:tensorflow:{'Loss/classification_loss': 0.109007366,
#  'Loss/localization_loss': 0.03970552,
#  'Loss/regularization_loss': 0.07206097,
#  'Loss/total_loss': 0.22077386,
#  'learning_rate': 0.03581886}
# I0424 00:57:45.309092 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.109007366,
#  'Loss/localization_loss': 0.03970552,
#  'Loss/regularization_loss': 0.07206097,
#  'Loss/total_loss': 0.22077386,
#  'learning_rate': 0.03581886}
# INFO:tensorflow:Step 27700 per-step time 0.227s
# I0424 00:58:08.012809 136340283929728 model_lib_v2.py:705] Step 27700 per-step time 0.227s
# INFO:tensorflow:{'Loss/classification_loss': 0.09200724,
#  'Loss/localization_loss': 0.02610427,
#  'Loss/regularization_loss': 0.07199702,
#  'Loss/total_loss': 0.19010854,
#  'learning_rate': 0.035558585}
# I0424 00:58:08.013215 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.09200724,
#  'Loss/localization_loss': 0.02610427,
#  'Loss/regularization_loss': 0.07199702,
#  'Loss/total_loss': 0.19010854,
#  'learning_rate': 0.035558585}
# INFO:tensorflow:Step 27800 per-step time 0.224s
# I0424 00:58:30.388582 136340283929728 model_lib_v2.py:705] Step 27800 per-step time 0.224s
# INFO:tensorflow:{'Loss/classification_loss': 0.11288243,
#  'Loss/localization_loss': 0.035329737,
#  'Loss/regularization_loss': 0.07190348,
#  'Loss/total_loss': 0.22011565,
#  'learning_rate': 0.0352985}
# I0424 00:58:30.388906 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.11288243,
#  'Loss/localization_loss': 0.035329737,
#  'Loss/regularization_loss': 0.07190348,
#  'Loss/total_loss': 0.22011565,
#  'learning_rate': 0.0352985}
# INFO:tensorflow:Step 27900 per-step time 0.228s
# I0424 00:58:53.157344 136340283929728 model_lib_v2.py:705] Step 27900 per-step time 0.228s
# INFO:tensorflow:{'Loss/classification_loss': 0.13235196,
#  'Loss/localization_loss': 0.060872905,
#  'Loss/regularization_loss': 0.07179541,
#  'Loss/total_loss': 0.26502028,
#  'learning_rate': 0.035038617}
# I0424 00:58:53.157678 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.13235196,
#  'Loss/localization_loss': 0.060872905,
#  'Loss/regularization_loss': 0.07179541,
#  'Loss/total_loss': 0.26502028,
#  'learning_rate': 0.035038617}
# INFO:tensorflow:Step 28000 per-step time 0.228s
# I0424 00:59:15.912856 136340283929728 model_lib_v2.py:705] Step 28000 per-step time 0.228s
# INFO:tensorflow:{'Loss/classification_loss': 0.18657327,
#  'Loss/localization_loss': 0.060000073,
#  'Loss/regularization_loss': 0.07170337,
#  'Loss/total_loss': 0.3182767,
#  'learning_rate': 0.03477895}
# I0424 00:59:15.913202 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.18657327,
#  'Loss/localization_loss': 0.060000073,
#  'Loss/regularization_loss': 0.07170337,
#  'Loss/total_loss': 0.3182767,
#  'learning_rate': 0.03477895}
# INFO:tensorflow:Step 28100 per-step time 0.233s
# I0424 00:59:39.183655 136340283929728 model_lib_v2.py:705] Step 28100 per-step time 0.233s
# INFO:tensorflow:{'Loss/classification_loss': 0.076876566,
#  'Loss/localization_loss': 0.024115464,
#  'Loss/regularization_loss': 0.07161484,
#  'Loss/total_loss': 0.17260687,
#  'learning_rate': 0.0345195}
# I0424 00:59:39.183975 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.076876566,
#  'Loss/localization_loss': 0.024115464,
#  'Loss/regularization_loss': 0.07161484,
#  'Loss/total_loss': 0.17260687,
#  'learning_rate': 0.0345195}
# INFO:tensorflow:Step 28200 per-step time 0.227s
# I0424 01:00:01.907448 136340283929728 model_lib_v2.py:705] Step 28200 per-step time 0.227s
# INFO:tensorflow:{'Loss/classification_loss': 0.12887762,
#  'Loss/localization_loss': 0.032573637,
#  'Loss/regularization_loss': 0.07152291,
#  'Loss/total_loss': 0.23297417,
#  'learning_rate': 0.034260295}
# I0424 01:00:01.907768 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.12887762,
#  'Loss/localization_loss': 0.032573637,
#  'Loss/regularization_loss': 0.07152291,
#  'Loss/total_loss': 0.23297417,
#  'learning_rate': 0.034260295}
# INFO:tensorflow:Step 28300 per-step time 0.232s
# I0424 01:00:25.093232 136340283929728 model_lib_v2.py:705] Step 28300 per-step time 0.232s
# INFO:tensorflow:{'Loss/classification_loss': 0.1463848,
#  'Loss/localization_loss': 0.03733217,
#  'Loss/regularization_loss': 0.07143835,
#  'Loss/total_loss': 0.25515532,
#  'learning_rate': 0.034001328}
# I0424 01:00:25.093648 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.1463848,
#  'Loss/localization_loss': 0.03733217,
#  'Loss/regularization_loss': 0.07143835,
#  'Loss/total_loss': 0.25515532,
#  'learning_rate': 0.034001328}
# INFO:tensorflow:Step 28400 per-step time 0.224s
# I0424 01:00:47.525785 136340283929728 model_lib_v2.py:705] Step 28400 per-step time 0.224s
# INFO:tensorflow:{'Loss/classification_loss': 0.12520719,
#  'Loss/localization_loss': 0.041227493,
#  'Loss/regularization_loss': 0.07134154,
#  'Loss/total_loss': 0.23777622,
#  'learning_rate': 0.03374262}
# I0424 01:00:47.526245 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.12520719,
#  'Loss/localization_loss': 0.041227493,
#  'Loss/regularization_loss': 0.07134154,
#  'Loss/total_loss': 0.23777622,
#  'learning_rate': 0.03374262}
# INFO:tensorflow:Step 28500 per-step time 0.229s
# I0424 01:01:10.454223 136340283929728 model_lib_v2.py:705] Step 28500 per-step time 0.229s
# INFO:tensorflow:{'Loss/classification_loss': 0.11766396,
#  'Loss/localization_loss': 0.035693955,
#  'Loss/regularization_loss': 0.07124871,
#  'Loss/total_loss': 0.22460662,
#  'learning_rate': 0.033484176}
# I0424 01:01:10.454557 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.11766396,
#  'Loss/localization_loss': 0.035693955,
#  'Loss/regularization_loss': 0.07124871,
#  'Loss/total_loss': 0.22460662,
#  'learning_rate': 0.033484176}
# INFO:tensorflow:Step 28600 per-step time 0.226s
# I0424 01:01:33.017284 136340283929728 model_lib_v2.py:705] Step 28600 per-step time 0.226s
# INFO:tensorflow:{'Loss/classification_loss': 0.115950644,
#  'Loss/localization_loss': 0.03886374,
#  'Loss/regularization_loss': 0.071158305,
#  'Loss/total_loss': 0.2259727,
#  'learning_rate': 0.033226017}
# I0424 01:01:33.017659 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.115950644,
#  'Loss/localization_loss': 0.03886374,
#  'Loss/regularization_loss': 0.071158305,
#  'Loss/total_loss': 0.2259727,
#  'learning_rate': 0.033226017}
# INFO:tensorflow:Step 28700 per-step time 0.224s
# I0424 01:01:55.454340 136340283929728 model_lib_v2.py:705] Step 28700 per-step time 0.224s
# INFO:tensorflow:{'Loss/classification_loss': 0.11457042,
#  'Loss/localization_loss': 0.02532716,
#  'Loss/regularization_loss': 0.07106699,
#  'Loss/total_loss': 0.21096456,
#  'learning_rate': 0.03296815}
# I0424 01:01:55.454688 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.11457042,
#  'Loss/localization_loss': 0.02532716,
#  'Loss/regularization_loss': 0.07106699,
#  'Loss/total_loss': 0.21096456,
#  'learning_rate': 0.03296815}
# INFO:tensorflow:Step 28800 per-step time 0.229s
# I0424 01:02:18.364203 136340283929728 model_lib_v2.py:705] Step 28800 per-step time 0.229s
# INFO:tensorflow:{'Loss/classification_loss': 0.08544535,
#  'Loss/localization_loss': 0.027613478,
#  'Loss/regularization_loss': 0.07097088,
#  'Loss/total_loss': 0.1840297,
#  'learning_rate': 0.032710575}
# I0424 01:02:18.364573 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.08544535,
#  'Loss/localization_loss': 0.027613478,
#  'Loss/regularization_loss': 0.07097088,
#  'Loss/total_loss': 0.1840297,
#  'learning_rate': 0.032710575}
# INFO:tensorflow:Step 28900 per-step time 0.227s
# I0424 01:02:41.055419 136340283929728 model_lib_v2.py:705] Step 28900 per-step time 0.227s
# INFO:tensorflow:{'Loss/classification_loss': 0.1545228,
#  'Loss/localization_loss': 0.04454465,
#  'Loss/regularization_loss': 0.07086584,
#  'Loss/total_loss': 0.26993328,
#  'learning_rate': 0.03245332}
# I0424 01:02:41.055793 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.1545228,
#  'Loss/localization_loss': 0.04454465,
#  'Loss/regularization_loss': 0.07086584,
#  'Loss/total_loss': 0.26993328,
#  'learning_rate': 0.03245332}
# INFO:tensorflow:Step 29000 per-step time 0.227s
# I0424 01:03:03.735824 136340283929728 model_lib_v2.py:705] Step 29000 per-step time 0.227s
# INFO:tensorflow:{'Loss/classification_loss': 0.09464161,
#  'Loss/localization_loss': 0.030926568,
#  'Loss/regularization_loss': 0.07077604,
#  'Loss/total_loss': 0.19634423,
#  'learning_rate': 0.032196384}
# I0424 01:03:03.736140 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.09464161,
#  'Loss/localization_loss': 0.030926568,
#  'Loss/regularization_loss': 0.07077604,
#  'Loss/total_loss': 0.19634423,
#  'learning_rate': 0.032196384}
# INFO:tensorflow:Step 29100 per-step time 0.238s
# I0424 01:03:27.555700 136340283929728 model_lib_v2.py:705] Step 29100 per-step time 0.238s
# INFO:tensorflow:{'Loss/classification_loss': 0.12836449,
#  'Loss/localization_loss': 0.033418156,
#  'Loss/regularization_loss': 0.07068477,
#  'Loss/total_loss': 0.23246741,
#  'learning_rate': 0.031939782}
# I0424 01:03:27.556034 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.12836449,
#  'Loss/localization_loss': 0.033418156,
#  'Loss/regularization_loss': 0.07068477,
#  'Loss/total_loss': 0.23246741,
#  'learning_rate': 0.031939782}
# INFO:tensorflow:Step 29200 per-step time 0.231s
# I0424 01:03:50.668521 136340283929728 model_lib_v2.py:705] Step 29200 per-step time 0.231s
# INFO:tensorflow:{'Loss/classification_loss': 0.104443364,
#  'Loss/localization_loss': 0.023787308,
#  'Loss/regularization_loss': 0.07060826,
#  'Loss/total_loss': 0.19883893,
#  'learning_rate': 0.03168353}
# I0424 01:03:50.668933 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.104443364,
#  'Loss/localization_loss': 0.023787308,
#  'Loss/regularization_loss': 0.07060826,
#  'Loss/total_loss': 0.19883893,
#  'learning_rate': 0.03168353}
# INFO:tensorflow:Step 29300 per-step time 0.228s
# I0424 01:04:13.495285 136340283929728 model_lib_v2.py:705] Step 29300 per-step time 0.228s
# INFO:tensorflow:{'Loss/classification_loss': 0.09292327,
#  'Loss/localization_loss': 0.029624037,
#  'Loss/regularization_loss': 0.07052404,
#  'Loss/total_loss': 0.19307134,
#  'learning_rate': 0.03142763}
# I0424 01:04:13.495646 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.09292327,
#  'Loss/localization_loss': 0.029624037,
#  'Loss/regularization_loss': 0.07052404,
#  'Loss/total_loss': 0.19307134,
#  'learning_rate': 0.03142763}
# INFO:tensorflow:Step 29400 per-step time 0.227s
# I0424 01:04:36.150494 136340283929728 model_lib_v2.py:705] Step 29400 per-step time 0.227s
# INFO:tensorflow:{'Loss/classification_loss': 0.09725348,
#  'Loss/localization_loss': 0.035464216,
#  'Loss/regularization_loss': 0.07044732,
#  'Loss/total_loss': 0.20316502,
#  'learning_rate': 0.031172099}
# I0424 01:04:36.150822 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.09725348,
#  'Loss/localization_loss': 0.035464216,
#  'Loss/regularization_loss': 0.07044732,
#  'Loss/total_loss': 0.20316502,
#  'learning_rate': 0.031172099}
# INFO:tensorflow:Step 29500 per-step time 0.224s
# I0424 01:04:58.562946 136340283929728 model_lib_v2.py:705] Step 29500 per-step time 0.224s
# INFO:tensorflow:{'Loss/classification_loss': 0.12818214,
#  'Loss/localization_loss': 0.028463555,
#  'Loss/regularization_loss': 0.07037476,
#  'Loss/total_loss': 0.22702046,
#  'learning_rate': 0.030916952}
# I0424 01:04:58.563290 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.12818214,
#  'Loss/localization_loss': 0.028463555,
#  'Loss/regularization_loss': 0.07037476,
#  'Loss/total_loss': 0.22702046,
#  'learning_rate': 0.030916952}
# INFO:tensorflow:Step 29600 per-step time 0.229s
# I0424 01:05:21.451730 136340283929728 model_lib_v2.py:705] Step 29600 per-step time 0.229s
# INFO:tensorflow:{'Loss/classification_loss': 0.1371056,
#  'Loss/localization_loss': 0.04779549,
#  'Loss/regularization_loss': 0.07028412,
#  'Loss/total_loss': 0.25518522,
#  'learning_rate': 0.030662183}
# I0424 01:05:21.452057 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.1371056,
#  'Loss/localization_loss': 0.04779549,
#  'Loss/regularization_loss': 0.07028412,
#  'Loss/total_loss': 0.25518522,
#  'learning_rate': 0.030662183}
# INFO:tensorflow:Step 29700 per-step time 0.227s
# I0424 01:05:44.190109 136340283929728 model_lib_v2.py:705] Step 29700 per-step time 0.227s
# INFO:tensorflow:{'Loss/classification_loss': 0.15021715,
#  'Loss/localization_loss': 0.04892842,
#  'Loss/regularization_loss': 0.07018977,
#  'Loss/total_loss': 0.26933533,
#  'learning_rate': 0.030407822}
# I0424 01:05:44.190432 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.15021715,
#  'Loss/localization_loss': 0.04892842,
#  'Loss/regularization_loss': 0.07018977,
#  'Loss/total_loss': 0.26933533,
#  'learning_rate': 0.030407822}
# INFO:tensorflow:Step 29800 per-step time 0.224s
# I0424 01:06:06.581491 136340283929728 model_lib_v2.py:705] Step 29800 per-step time 0.224s
# INFO:tensorflow:{'Loss/classification_loss': 0.08677607,
#  'Loss/localization_loss': 0.03164792,
#  'Loss/regularization_loss': 0.07010107,
#  'Loss/total_loss': 0.18852505,
#  'learning_rate': 0.030153865}
# I0424 01:06:06.581820 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.08677607,
#  'Loss/localization_loss': 0.03164792,
#  'Loss/regularization_loss': 0.07010107,
#  'Loss/total_loss': 0.18852505,
#  'learning_rate': 0.030153865}
# INFO:tensorflow:Step 29900 per-step time 0.229s
# I0424 01:06:29.451792 136340283929728 model_lib_v2.py:705] Step 29900 per-step time 0.229s
# INFO:tensorflow:{'Loss/classification_loss': 0.08692234,
#  'Loss/localization_loss': 0.021837307,
#  'Loss/regularization_loss': 0.07000838,
#  'Loss/total_loss': 0.17876804,
#  'learning_rate': 0.029900335}
# I0424 01:06:29.452108 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.08692234,
#  'Loss/localization_loss': 0.021837307,
#  'Loss/regularization_loss': 0.07000838,
#  'Loss/total_loss': 0.17876804,
#  'learning_rate': 0.029900335}
# INFO:tensorflow:Step 30000 per-step time 0.229s
# I0424 01:06:52.333514 136340283929728 model_lib_v2.py:705] Step 30000 per-step time 0.229s
# INFO:tensorflow:{'Loss/classification_loss': 0.10046102,
#  'Loss/localization_loss': 0.03290358,
#  'Loss/regularization_loss': 0.0699286,
#  'Loss/total_loss': 0.2032932,
#  'learning_rate': 0.02964724}
# I0424 01:06:52.333910 136340283929728 model_lib_v2.py:708] {'Loss/classification_loss': 0.10046102,
#  'Loss/localization_loss': 0.03290358,
#  'Loss/regularization_loss': 0.0699286,
#  'Loss/total_loss': 0.2032932,
#  'learning_rate': 0.02964724}

# %%
# !mkdir /content/custom_model_lite
output_directory = '/content/custom_model_lite'

last_model_path = '/content/training'

# !python /content/models/research/object_detection/export_tflite_graph_tf2.py \
    --trained_checkpoint_dir {last_model_path} \
    --output_directory {output_directory} \
    --pipeline_config_path {pipeline_file}
# Out:
# 2024-04-24 01:07:01.934924: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0424 01:07:06.787379 139114113582208 api.py:441] feature_map_spatial_dims: [(19, 19), (10, 10), (5, 5), (3, 3), (2, 2), (1, 1)]
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0424 01:07:09.697555 139114113582208 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0424 01:07:09.697850 139114113582208 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0424 01:07:09.698007 139114113582208 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0424 01:07:09.698134 139114113582208 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0424 01:07:09.698256 139114113582208 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0424 01:07:09.698376 139114113582208 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# I0424 01:07:11.226374 139114113582208 api.py:441] feature_map_spatial_dims: [(19, 19), (10, 10), (5, 5), (3, 3), (2, 2), (1, 1)]
# 2024-04-24 01:07:12.446701: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# I0424 01:07:13.052200 139114113582208 api.py:441] feature_map_spatial_dims: [(19, 19), (10, 10), (5, 5), (3, 3), (2, 2), (1, 1)]
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7e858b5243a0>, because it is not built.
# W0424 01:07:13.976685 139114113582208 save_impl.py:71] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7e858b5243a0>, because it is not built.
# W0424 01:07:33.808360 139114113582208 save.py:260] Found untraced functions such as BoxPredictor_layer_call_fn, BoxPredictor_layer_call_and_return_conditional_losses, ConvolutionalBoxHead_0_layer_call_fn, ConvolutionalBoxHead_0_layer_call_and_return_conditional_losses, ConvolutionalBoxHead_1_layer_call_fn while saving (showing 5 of 50). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/custom_model_lite/saved_model/assets
# I0424 01:07:38.000974 139114113582208 builder_impl.py:779] Assets written to: /content/custom_model_lite/saved_model/assets

# %%
import tensorflow as tf

converter = tf.lite.TFLiteConverter.from_saved_model('/content/custom_model_lite/saved_model')
tflite_model = converter.convert()

with open('/content/custom_model_lite/detect.tflite', 'wb') as f:
  f.write(tflite_model)

# %%
# Move labelmap and pipeline config files into TFLite model folder and zip it up
# !cp /content/labelmap.txt /content/custom_model_lite
# !cp /content/labelmap.pbtxt /content/custom_model_lite
# !cp /content/models/mymodel/pipeline_file.config /content/custom_model_lite

# %cd /content
# !zip -r custom_model_lite.zip custom_model_lite
# Out:
# /content
#   adding: custom_model_lite/ (stored 0%)
#   adding: custom_model_lite/saved_model/ (stored 0%)
#   adding: custom_model_lite/saved_model/saved_model.pb (deflated 92%)
#   adding: custom_model_lite/saved_model/assets/ (stored 0%)
#   adding: custom_model_lite/saved_model/variables/ (stored 0%)
#   adding: custom_model_lite/saved_model/variables/variables.index (deflated 76%)
#   adding: custom_model_lite/saved_model/variables/variables.data-00000-of-00001 (deflated 8%)
#   adding: custom_model_lite/labelmap.txt (deflated 25%)
#   adding: custom_model_lite/labelmap.pbtxt (deflated 64%)
#   adding: custom_model_lite/pipeline_file.config (deflated 67%)
#   adding: custom_model_lite/detect.tflite (deflated 7%)

# %%
from google.colab import files

files.download('/content/custom_model_lite.zip')
